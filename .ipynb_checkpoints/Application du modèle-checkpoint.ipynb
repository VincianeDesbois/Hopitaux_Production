# %% [markdown]
# # Application du modèle économétrique

# %% [markdown]
# Nous allons appliquer notre modèle translog aux différentes variables construites précédemment.

# %%
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import statsmodels.api as sm

# %% [markdown]
# ## 1. Construction de la base nécessaire à l'application du modèle

# %% [markdown]
# On crée une base contenant la variable d'intérêt Y (les points ISA), les variables explicatives et les variables de contrôle.

# %%
VAR_EXPL = pd.read_csv('C:/Users/mille/OneDrive/Documents/ENSAE/2ème année/Stat App/VAR_EXPL.csv')
VAR_EXPL_SPL = pd.read_csv('C:/Users/mille/OneDrive/Documents/ENSAE/2ème année/Stat App/VAR_EXPL_SPL.csv')
VAR_CTRL = pd.read_csv('C:/Users/mille/OneDrive/Documents/GitHub/Hopitaux_Production/Variables_controle.csv')
VAR_CTRL
# Out:
#      Numero_finess     Points_ISA  stjr dep      Departement COMINSEE  \
# 0        060000528  356892.030000     3  06  Alpes-Maritimes    06088
# 1        060780947  174552.540000     3  06  Alpes-Maritimes    06088
# 2        060791811  146432.633333     3  06  Alpes-Maritimes    06088
# 3        060780442   22842.380000     2  06  Alpes-Maritimes    06088
# 4        060780715  342051.171667     2  06  Alpes-Maritimes    06088
# ...            ...            ...   ...  ..              ...      ...
# 1155     120780085   45665.700000     1  12          Aveyron    12089
# 1156     480780097  240863.268333     1  48           Lozère    48095
# 1157     480780162    5699.150000     1  48           Lozère    48080
# 1158     480780121    2396.450000     1  48           Lozère    48140
# 1159     480780154     517.680000     1  48           Lozère    48092
#
#       Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  \
# 0               128.0           8.0               9.0
# 1               105.0           5.0               4.0
# 2                91.0           2.0               2.0
# 3                30.0           6.0               1.0
# 4               256.0          26.0              10.0
# ...               ...           ...               ...
# 1155             34.0           5.0               3.0
# 1156             67.0           6.0               6.0
# 1157             23.0           0.0               1.0
# 1158             22.0           0.0               0.0
# 1159             20.0           0.0               0.0
#
#       Capital_Examens_biologiques  ...  SEJHC_OBS  SEJHC_MCO  \
# 0                           909.0  ...        0.0     7020.0
# 1                             0.0  ...        0.0     9754.0
# 2                             0.0  ...        0.0     2558.0
# 3                             0.0  ...        0.0     1605.0
# 4                             0.0  ...     1467.0    15866.0
# ...                           ...  ...        ...        ...
# 1155                     235068.0  ...        0.0     2056.0
# 1156                     423436.0  ...      392.0     3599.5
# 1157                          0.0  ...        0.0      421.0
# 1158                          0.0  ...        0.0      205.0
# 1159                          0.0  ...        0.0      384.0
#
#       Taux_chomage_par_dep  Population  Dep Moyenne Salaires Horaires  \
# 0                      8.9    343123.0                      12.579245
# 1                      8.9    343123.0                      12.579245
# 2                      8.9    343123.0                      12.579245
# 3                      8.9    343123.0                      12.579245
# 4                      8.9    343123.0                      12.579245
# ...                    ...         ...                            ...
# 1155                   6.4      6787.0                      10.115789
# 1156                   5.3     11792.0                      10.075000
# 1157                   5.3      3097.0                      10.075000
# 1158                   5.3      4319.0                      10.075000
# 1159                   5.3      5504.0                      10.075000
#
#       Dep Moyenne Salaires Cadre Horaires  \
# 0                               22.518868
# 1                               22.518868
# 2                               22.518868
# 3                               22.518868
# 4                               22.518868
# ...                                   ...
# 1155                            20.252632
# 1156                            20.475000
# 1157                            20.475000
# 1158                            20.475000
# 1159                            20.475000
#
#       Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                            12.864151
# 1                                            12.864151
# 2                                            12.864151
# 3                                            12.864151
# 4                                            12.864151
# ...                                                ...
# 1155                                         11.963158
# 1156                                         11.775000
# 1157                                         11.775000
# 1158                                         11.775000
# 1159                                         11.775000
#
#       Dep Moyenne Salaires Employé Horaires  \
# 0                                  8.835849
# 1                                  8.835849
# 2                                  8.835849
# 3                                  8.835849
# 4                                  8.835849
# ...                                     ...
# 1155                               8.478947
# 1156                               8.600000
# 1157                               8.600000
# 1158                               8.600000
# 1159                               8.600000
#
#       Moyenne Revenus Fiscaux Départementaux                Bloc_politique
# 0                                    12288.0         Centre droit à droite
# 1                                    12288.0         Centre droit à droite
# 2                                    12288.0         Centre droit à droite
# 3                                    12288.0         Centre droit à droite
# 4                                    12288.0         Centre droit à droite
# ...                                      ...                           ...
# 1155                                  9936.0       Extrême gauche à gauche
# 1156                                  8555.0  Centre gauche à centre droit
# 1157                                  8555.0  Centre gauche à centre droit
# 1158                                  8555.0         Centre droit à droite
# 1159                                  8555.0         Centre droit à droite
#
# [1160 rows x 23 columns]

# %%
del VAR_EXPL['Unnamed: 0']
del VAR_EXPL_SPL['Unnamed: 0']

# %%
VAR_EXPL.columns
# Out:
# Index(['Numero_finess', 'Médecins libéraux',
#        'Autres personnels médicaux libéraux', 'Médecins salariés',
#        'Autres personnels médicaux salariés',
#        'Personnels de direction et administratifs',
#        'Personnels des services de soins', 'Personnels éducatifs et sociaux',
#        'Personnels médico-techniques', 'Personnels techniques et ouvriers',
#        'Points_ISA', 'stjr', 'Internes'],
#       dtype='object')

# %%
df = pd.merge(VAR_EXPL, VAR_CTRL, on=['Numero_finess'])
df.rename(columns = {'Points_ISA_x': 'Points_ISA', 'stjr_x': 'stjr'}, inplace=True)
df.drop(['Points_ISA_y','stjr_y'], axis=1, inplace=True)

# %%
df = pd.merge(df, VAR_EXPL_SPL)
df
# Out:
#      Numero_finess  Médecins libéraux  Autres personnels médicaux libéraux  \
# 0        010007300                4.5                                  3.0
# 1        010008407                0.0                                  0.0
# 2        010009132                0.0                                  0.0
# 3        010780054                4.5                                  1.0
# 4        010780062                0.0                                  0.0
# ...            ...                ...                                  ...
# 1145     950300277               29.5                                 16.0
# 1146     950300301                2.0                                  0.5
# 1147     950300350                5.5                                  6.5
# 1148     950630012                0.0                                  0.0
# 1149     950807982               33.0                                 38.5
#
#       Médecins salariés  Autres personnels médicaux salariés  \
# 0                 0.000                                 0.00
# 1                18.490                                14.33
# 2                 1.795                                 0.07
# 3               102.600                                44.53
# 4                19.450                                10.10
# ...                 ...                                  ...
# 1145              4.060                                 3.00
# 1146              6.970                                 1.80
# 1147              1.000                                 0.80
# 1148             11.300                                 2.50
# 1149              1.300                                 3.00
#
#       Personnels de direction et administratifs  \
# 0                                      2.250000
# 1                                     21.196667
# 2                                      4.175000
# 3                                    118.605000
# 4                                     58.450000
# ...                                         ...
# 1145                                  74.950000
# 1146                                  22.560000
# 1147                                   6.600000
# 1148                                  23.070000
# 1149                                  61.000000
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             4.200000                              NaN
# 1                            97.323333                         0.846667
# 2                            46.700000                         1.065000
# 3                           388.590000                         4.930000
# 4                           336.540000                         5.450000
# ...                                ...                              ...
# 1145                        246.990000                         1.100000
# 1146                        103.560000                         1.380000
# 1147                         27.550000                              NaN
# 1148                        177.880000                        39.070000
# 1149                        288.230000                         1.130000
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  ...  \
# 0                              NaN                                NaN  ...
# 1                         9.206667                             26.440  ...
# 2                         1.130000                             13.465  ...
# 3                       107.660000                            112.630  ...
# 4                        29.320000                             57.570  ...
# ...                            ...                                ...  ...
# 1145                      6.460000                             14.460  ...
# 1146                      2.940000                              3.000  ...
# 1147                      3.000000                              1.000  ...
# 1148                      5.330000                             12.700  ...
# 1149                      7.690000                              6.000  ...
#
#       Dep Moyenne Salaires Horaires  Dep Moyenne Salaires Cadre Horaires  \
# 0                         11.410345                            21.963793
# 1                         11.410345                            21.963793
# 2                         11.410345                            21.963793
# 3                         11.410345                            21.963793
# 4                         11.410345                            21.963793
# ...                             ...                                  ...
# 1145                      13.710526                            22.919737
# 1146                      13.710526                            22.919737
# 1147                      13.710526                            22.919737
# 1148                      13.710526                            22.919737
# 1149                      13.710526                            22.919737
#
#       Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                            12.558621
# 1                                            12.558621
# 2                                            12.558621
# 3                                            12.558621
# 4                                            12.558621
# ...                                                ...
# 1145                                         13.531579
# 1146                                         13.531579
# 1147                                         13.531579
# 1148                                         13.531579
# 1149                                         13.531579
#
#      Dep Moyenne Salaires Employé Horaires  \
# 0                                 8.743103
# 1                                 8.743103
# 2                                 8.743103
# 3                                 8.743103
# 4                                 8.743103
# ...                                    ...
# 1145                              9.663158
# 1146                              9.663158
# 1147                              9.663158
# 1148                              9.663158
# 1149                              9.663158
#
#      Moyenne Revenus Fiscaux Départementaux                Bloc_politique  \
# 0                                   12509.0  Centre gauche à centre droit
# 1                                   12509.0       Droite à extrême droite
# 2                                   12509.0       Droite à extrême droite
# 3                                   12509.0         Centre droit à droite
# 4                                   12509.0  Centre gauche à centre droit
# ...                                     ...                           ...
# 1145                                 8826.0       Extrême gauche à gauche
# 1146                                 8826.0       Extrême gauche à gauche
# 1147                                 8826.0  Centre gauche à centre droit
# 1148                                 8826.0  Centre gauche à centre droit
# 1149                                 8826.0  Centre gauche à centre droit
#
#       Personnel médical  Autre sans internes  \
# 0                 7.500                  NaN
# 1                32.820               57.690
# 2                 1.865               19.835
# 3               152.630              343.825
# 4                29.550              150.790
# ...                 ...                  ...
# 1145             52.560               96.970
# 1146             11.270               29.880
# 1147             13.800                  NaN
# 1148             13.800               80.170
# 1149             75.800               75.820
#
#       Autre sans direction et administratif  Autre sans techniques et ouvriers
# 0                                       NaN                                NaN
# 1                                 36.493333                             31.250
# 2                                 15.660000                              6.370
# 3                                420.310000                            426.285
# 4                                 98.790000                             99.670
# ...                                     ...                                ...
# 1145                              22.020000                             82.510
# 1146                               7.320000                             26.880
# 1147                                    NaN                                NaN
# 1148                              59.590000                             69.960
# 1149                              14.820000                             69.820
#
# [1150 rows x 37 columns]

# %% [markdown]
# On obtient bien 1152 établissements (inchallah), le nombre d'établissements qui avaient des données dans les bases du personnel. On n'a donc pas pris en compte les établissements présents dans la base des variables explicatives mais dont on ne pouvait rien dire, faute de données sur leur personnel.

# %% [markdown]
# On construit des variables plus générales pour nos premières analyses : on regroupe les différentes mesures des ressources techniques des hôpitaux dans la variable Capital_Tech et les différents types de personnels libéraux et salariés dans les mêmes catégorie.

# %%
df = df.assign(Capital_tech = df['Capital_Bloc'] + df['Capital_imagerie'] + df['Capital_Examens_biologiques'] 
               + df['Capital_telemed'], 
              Médecins = df['Médecins libéraux'] + df['Médecins salariés'],
              Autres_personnels_médicaux = df['Autres personnels médicaux libéraux'] +df['Autres personnels médicaux salariés'])
df
# Out:
#      Numero_finess  Médecins libéraux  Autres personnels médicaux libéraux  \
# 0        010007300                4.5                                  3.0
# 1        010008407                0.0                                  0.0
# 2        010009132                0.0                                  0.0
# 3        010780054                4.5                                  1.0
# 4        010780062                0.0                                  0.0
# ...            ...                ...                                  ...
# 1145     950300277               29.5                                 16.0
# 1146     950300301                2.0                                  0.5
# 1147     950300350                5.5                                  6.5
# 1148     950630012                0.0                                  0.0
# 1149     950807982               33.0                                 38.5
#
#       Médecins salariés  Autres personnels médicaux salariés  \
# 0                 0.000                                 0.00
# 1                18.490                                14.33
# 2                 1.795                                 0.07
# 3               102.600                                44.53
# 4                19.450                                10.10
# ...                 ...                                  ...
# 1145              4.060                                 3.00
# 1146              6.970                                 1.80
# 1147              1.000                                 0.80
# 1148             11.300                                 2.50
# 1149              1.300                                 3.00
#
#       Personnels de direction et administratifs  \
# 0                                      2.250000
# 1                                     21.196667
# 2                                      4.175000
# 3                                    118.605000
# 4                                     58.450000
# ...                                         ...
# 1145                                  74.950000
# 1146                                  22.560000
# 1147                                   6.600000
# 1148                                  23.070000
# 1149                                  61.000000
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             4.200000                              NaN
# 1                            97.323333                         0.846667
# 2                            46.700000                         1.065000
# 3                           388.590000                         4.930000
# 4                           336.540000                         5.450000
# ...                                ...                              ...
# 1145                        246.990000                         1.100000
# 1146                        103.560000                         1.380000
# 1147                         27.550000                              NaN
# 1148                        177.880000                        39.070000
# 1149                        288.230000                         1.130000
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  ...  \
# 0                              NaN                                NaN  ...
# 1                         9.206667                             26.440  ...
# 2                         1.130000                             13.465  ...
# 3                       107.660000                            112.630  ...
# 4                        29.320000                             57.570  ...
# ...                            ...                                ...  ...
# 1145                      6.460000                             14.460  ...
# 1146                      2.940000                              3.000  ...
# 1147                      3.000000                              1.000  ...
# 1148                      5.330000                             12.700  ...
# 1149                      7.690000                              6.000  ...
#
#       Dep Moyenne Salaires Employé Horaires  \
# 0                                  8.743103
# 1                                  8.743103
# 2                                  8.743103
# 3                                  8.743103
# 4                                  8.743103
# ...                                     ...
# 1145                               9.663158
# 1146                               9.663158
# 1147                               9.663158
# 1148                               9.663158
# 1149                               9.663158
#
#       Moyenne Revenus Fiscaux Départementaux                Bloc_politique  \
# 0                                    12509.0  Centre gauche à centre droit
# 1                                    12509.0       Droite à extrême droite
# 2                                    12509.0       Droite à extrême droite
# 3                                    12509.0         Centre droit à droite
# 4                                    12509.0  Centre gauche à centre droit
# ...                                      ...                           ...
# 1145                                  8826.0       Extrême gauche à gauche
# 1146                                  8826.0       Extrême gauche à gauche
# 1147                                  8826.0  Centre gauche à centre droit
# 1148                                  8826.0  Centre gauche à centre droit
# 1149                                  8826.0  Centre gauche à centre droit
#
#      Personnel médical Autre sans internes  \
# 0                7.500                 NaN
# 1               32.820              57.690
# 2                1.865              19.835
# 3              152.630             343.825
# 4               29.550             150.790
# ...                ...                 ...
# 1145            52.560              96.970
# 1146            11.270              29.880
# 1147            13.800                 NaN
# 1148            13.800              80.170
# 1149            75.800              75.820
#
#      Autre sans direction et administratif  Autre sans techniques et ouvriers  \
# 0                                      NaN                                NaN
# 1                                36.493333                             31.250
# 2                                15.660000                              6.370
# 3                               420.310000                            426.285
# 4                                98.790000                             99.670
# ...                                    ...                                ...
# 1145                             22.020000                             82.510
# 1146                              7.320000                             26.880
# 1147                                   NaN                                NaN
# 1148                             59.590000                             69.960
# 1149                             14.820000                             69.820
#
#       Capital_tech  Médecins  Autres_personnels_médicaux
# 0              1.0     4.500                        3.00
# 1         265754.0    18.490                       14.33
# 2              0.0     1.795                        0.07
# 3         954720.0   107.100                       45.53
# 4              8.0    19.450                       10.10
# ...            ...       ...                         ...
# 1145           8.0    33.560                       19.00
# 1146           0.0     8.970                        2.30
# 1147           7.0     6.500                        7.30
# 1148           0.0    11.300                        2.50
# 1149      183658.0    34.300                       41.50
#
# [1150 rows x 40 columns]

# %% [markdown]
# Nous décidons de traiter les valeurs manquantes en les remplaçant par des valeurs nulles. Nous montrerons plus tard que cela n'affecte pas nos résultats.

# %%
df_nanull = df.fillna(0)

# %%
df.columns
# Out:
# Index(['Numero_finess', 'Médecins libéraux',
#        'Autres personnels médicaux libéraux', 'Médecins salariés',
#        'Autres personnels médicaux salariés',
#        'Personnels de direction et administratifs',
#        'Personnels des services de soins', 'Personnels éducatifs et sociaux',
#        'Personnels médico-techniques', 'Personnels techniques et ouvriers',
#        'Points_ISA', 'stjr', 'Internes', 'dep', 'Departement', 'COMINSEE',
#        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
#        'Capital_Examens_biologiques', 'Capital_telemed', 'SEJHC_MED',
#        'SEJHC_CHI', 'SEJHC_OBS', 'SEJHC_MCO', 'Taux_chomage_par_dep',
#        'Population', 'Dep Moyenne Salaires Horaires',
#        'Dep Moyenne Salaires Cadre Horaires',
#        'Dep Moyenne Salaires Prof Intermédiaire Horaires',
#        'Dep Moyenne Salaires Employé Horaires',
#        'Moyenne Revenus Fiscaux Départementaux', 'Bloc_politique',
#        'Personnel médical', 'Autre sans internes',
#        'Autre sans direction et administratif',
#        'Autre sans techniques et ouvriers', 'Capital_tech', 'Médecins',
#        'Autres_personnels_médicaux'],
#       dtype='object')

# %%
#Nous passons en log tous les variables que l'on va utiliser comme facteur de production dans notre fonction translog

df_log = df_nanull.apply(lambda x: np.log(x) if x.name in ['Médecins libéraux', 'Autres personnels médicaux libéraux', 
                                                    'Médecins salariés', 'Autres personnels médicaux salariés',
                                                    'Médecins', 'Autres_personnels_médicaux',      
                                                    'Personnels de direction et administratifs',
                                                    'Personnels des services de soins', 'Personnels éducatifs et sociaux',
                                                    'Personnels médico-techniques', 'Personnels techniques et ouvriers',
                                                    'Personnel médical', 'Autre sans internes',
                                                    'Autre sans direction et administratif',
                                                    'Autre sans techniques et ouvriers',
                                                    'Points_ISA', 'Internes', 'Capital_Lit_MCO',
                                                    'Capital_Bloc', 'Capital_imagerie', 'Capital_Examens_biologiques',
                                                    'Capital_telemed', 'Capital_tech'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
df_log = df_log.replace(-inf, -3)

df_log
# Out:
# C:\Users\mille\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Numero_finess  Médecins libéraux  Autres personnels médicaux libéraux  \
# 0        010007300           1.504077                             1.098612
# 1        010008407          -3.000000                            -3.000000
# 2        010009132          -3.000000                            -3.000000
# 3        010780054           1.504077                             0.000000
# 4        010780062          -3.000000                            -3.000000
# ...            ...                ...                                  ...
# 1145     950300277           3.384390                             2.772589
# 1146     950300301           0.693147                            -0.693147
# 1147     950300350           1.704748                             1.871802
# 1148     950630012          -3.000000                            -3.000000
# 1149     950807982           3.496508                             3.650658
#
#       Médecins salariés  Autres personnels médicaux salariés  \
# 0             -3.000000                            -3.000000
# 1              2.917230                             2.662355
# 2              0.585005                            -2.659260
# 3              4.630838                             3.796163
# 4              2.967847                             2.312535
# ...                 ...                                  ...
# 1145           1.401183                             1.098612
# 1146           1.941615                             0.587787
# 1147           0.000000                            -0.223144
# 1148           2.424803                             0.916291
# 1149           0.262364                             1.098612
#
#       Personnels de direction et administratifs  \
# 0                                      0.810930
# 1                                      3.053844
# 2                                      1.429114
# 3                                      4.775799
# 4                                      4.068172
# ...                                         ...
# 1145                                   4.316821
# 1146                                   3.116178
# 1147                                   1.887070
# 1148                                   3.138533
# 1149                                   4.110874
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             1.435085                        -3.000000
# 1                             4.578039                        -0.166448
# 2                             3.843744                         0.062975
# 3                             5.962525                         1.595339
# 4                             5.818717                         1.695616
# ...                                ...                              ...
# 1145                          5.509348                         0.095310
# 1146                          4.640151                         0.322083
# 1147                          3.316003                        -3.000000
# 1148                          5.181109                         3.665355
# 1149                          5.663759                         0.122218
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  ...  \
# 0                        -3.000000                          -3.000000  ...
# 1                         2.219928                           3.274878  ...
# 2                         0.122218                           2.600094  ...
# 3                         4.678978                           4.724108  ...
# 4                         3.378270                           4.053002  ...
# ...                            ...                                ...  ...
# 1145                      1.865629                           2.671386  ...
# 1146                      1.078410                           1.098612  ...
# 1147                      1.098612                           0.000000  ...
# 1148                      1.673351                           2.541602  ...
# 1149                      2.039921                           1.791759  ...
#
#       Dep Moyenne Salaires Employé Horaires  \
# 0                                  8.743103
# 1                                  8.743103
# 2                                  8.743103
# 3                                  8.743103
# 4                                  8.743103
# ...                                     ...
# 1145                               9.663158
# 1146                               9.663158
# 1147                               9.663158
# 1148                               9.663158
# 1149                               9.663158
#
#       Moyenne Revenus Fiscaux Départementaux                Bloc_politique  \
# 0                                    12509.0  Centre gauche à centre droit
# 1                                    12509.0       Droite à extrême droite
# 2                                    12509.0       Droite à extrême droite
# 3                                    12509.0         Centre droit à droite
# 4                                    12509.0  Centre gauche à centre droit
# ...                                      ...                           ...
# 1145                                  8826.0       Extrême gauche à gauche
# 1146                                  8826.0       Extrême gauche à gauche
# 1147                                  8826.0  Centre gauche à centre droit
# 1148                                  8826.0  Centre gauche à centre droit
# 1149                                  8826.0  Centre gauche à centre droit
#
#      Personnel médical Autre sans internes  \
# 0             2.014903           -3.000000
# 1             3.491038            4.055084
# 2             0.623261            2.987448
# 3             5.028017            5.840133
# 4             3.386084            5.015888
# ...                ...                 ...
# 1145          3.961955            4.574402
# 1146          2.422144            3.397189
# 1147          2.624669           -3.000000
# 1148          2.624669            4.384149
# 1149          4.328098            4.328362
#
#      Autre sans direction et administratif  Autre sans techniques et ouvriers  \
# 0                                -3.000000                          -3.000000
# 1                                 3.597130                           3.442019
# 2                                 2.751110                           1.851599
# 3                                 6.040993                           6.055108
# 4                                 4.592996                           4.601865
# ...                                    ...                                ...
# 1145                              3.091951                           4.412919
# 1146                              1.990610                           3.291383
# 1147                             -3.000000                          -3.000000
# 1148                              4.087488                           4.247924
# 1149                              2.695978                           4.245921
#
#       Capital_tech  Médecins  Autres_personnels_médicaux
# 0         0.000000  1.504077                    1.098612
# 1        12.490326  2.917230                    2.662355
# 2        -3.000000  0.585005                   -2.659260
# 3        13.769173  4.673763                    3.818371
# 4         2.079442  2.967847                    2.312535
# ...            ...       ...                         ...
# 1145      2.079442  3.513335                    2.944439
# 1146     -3.000000  2.193886                    0.832909
# 1147      1.945910  1.871802                    1.987874
# 1148     -3.000000  2.424803                    0.916291
# 1149     12.120831  3.535145                    3.725693
#
# [1150 rows x 40 columns]

# %%
dfm = df_log.copy()
for i in ['Personnel médical', 'Autre sans internes',
            'Autre sans direction et administratif',
            'Autre sans techniques et ouvriers',
            'Personnels de direction et administratifs',
            'Personnels des services de soins',
            'Personnels techniques et ouvriers',
            'Internes', 'Capital_Lit_MCO','Capital_tech',
             'Capital_Bloc', 'Capital_imagerie', 'Capital_Examens_biologiques']:
    for j in ['Personnel médical', 'Autre sans internes',
            'Autre sans direction et administratif',
            'Autre sans techniques et ouvriers',
            'Personnels de direction et administratifs',
            'Personnels des services de soins',
            'Personnels techniques et ouvriers',
            'Internes', 'Capital_Lit_MCO','Capital_tech',
            'Capital_Bloc', 'Capital_imagerie', 'Capital_Examens_biologiques']:
        if i >= j :
            dfm.insert(0, i + ' x ' + j, df_log[i]*df_log[j])
    
dfm
# Out:
#       Capital_Examens_biologiques x Capital_Examens_biologiques  \
# 0                                              9.000000
# 1                                            156.007124
# 2                                              9.000000
# 3                                            189.589443
# 4                                              9.000000
# ...                                                 ...
# 1145                                           9.000000
# 1146                                           9.000000
# 1147                                           9.000000
# 1148                                           9.000000
# 1149                                         146.911499
#
#       Capital_Examens_biologiques x Capital_Bloc  \
# 0                                      -0.000000
# 1                                      24.304965
# 2                                       9.000000
# 3                                      34.215048
# 4                                      -4.158883
# ...                                          ...
# 1145                                   -6.238325
# 1146                                    9.000000
# 1147                                   -4.158883
# 1148                                    9.000000
# 1149                                   35.688677
#
#       Capital_Examens_biologiques x Autre sans techniques et ouvriers  \
# 0                                              9.000000
# 1                                             42.991790
# 2                                             -5.554798
# 3                                             83.373682
# 4                                            -13.805594
# ...                                                 ...
# 1145                                         -13.238758
# 1146                                          -9.874148
# 1147                                           9.000000
# 1148                                         -12.743771
# 1149                                          51.463551
#
#       Capital_Examens_biologiques x Autre sans direction et administratif  \
# 0                                              9.000000
# 1                                             44.929160
# 2                                             -8.253329
# 3                                             83.179322
# 4                                            -13.778989
# ...                                                 ...
# 1145                                          -9.275853
# 1146                                          -5.971831
# 1147                                           9.000000
# 1148                                         -12.262463
# 1149                                          32.677150
#
#       Capital_Examens_biologiques x Autre sans internes  \
# 0                                              9.000000
# 1                                             50.649138
# 2                                             -8.962344
# 3                                             80.413654
# 4                                            -15.047664
# ...                                                 ...
# 1145                                         -13.723205
# 1146                                         -10.191568
# 1147                                           9.000000
# 1148                                         -13.152448
# 1149                                          52.462802
#
#       Capital_imagerie x Capital_Examens_biologiques  \
# 0                                           9.000000
# 1                                          20.102332
# 2                                           9.000000
# 3                                          31.704635
# 4                                          -4.158883
# ...                                              ...
# 1145                                        9.000000
# 1146                                        9.000000
# 1147                                       -3.295837
# 1148                                        9.000000
# 1149                                       16.802866
#
#       Capital_imagerie x Capital_imagerie  Capital_imagerie x Capital_Bloc  \
# 0                                9.000000                        -0.000000
# 1                                2.590290                         3.131822
# 2                                9.000000                         9.000000
# 3                                5.301898                         5.721709
# 4                                1.921812                         1.921812
# ...                                   ...                              ...
# 1145                             9.000000                        -6.238325
# 1146                             9.000000                         9.000000
# 1147                             1.206949                         1.523000
# 1148                             9.000000                         9.000000
# 1149                             1.921812                         4.081859
#
#       Capital_imagerie x Capital_Lit_MCO  \
# 0                               9.000000
# 1                               7.443607
# 2                              -6.907755
# 3                              13.610112
# 4                               6.283517
# ...                                  ...
# 1145                          -14.648406
# 1146                           -9.133567
# 1147                            3.491449
# 1148                           -4.828314
# 1149                            6.625272
#
#       Capital_imagerie x Autre sans techniques et ouvriers  ...  \
# 0                                              9.000000     ...
# 1                                              5.539716     ...
# 2                                             -5.554798     ...
# 3                                             13.942402     ...
# 4                                              6.379539     ...
# ...                                                 ...     ...
# 1145                                         -13.238758     ...
# 1146                                          -9.874148     ...
# 1147                                          -3.295837     ...
# 1148                                         -12.743771     ...
# 1149                                           5.886096     ...
#
#       Dep Moyenne Salaires Employé Horaires  \
# 0                                  8.743103
# 1                                  8.743103
# 2                                  8.743103
# 3                                  8.743103
# 4                                  8.743103
# ...                                     ...
# 1145                               9.663158
# 1146                               9.663158
# 1147                               9.663158
# 1148                               9.663158
# 1149                               9.663158
#
#       Moyenne Revenus Fiscaux Départementaux                Bloc_politique  \
# 0                                    12509.0  Centre gauche à centre droit
# 1                                    12509.0       Droite à extrême droite
# 2                                    12509.0       Droite à extrême droite
# 3                                    12509.0         Centre droit à droite
# 4                                    12509.0  Centre gauche à centre droit
# ...                                      ...                           ...
# 1145                                  8826.0       Extrême gauche à gauche
# 1146                                  8826.0       Extrême gauche à gauche
# 1147                                  8826.0  Centre gauche à centre droit
# 1148                                  8826.0  Centre gauche à centre droit
# 1149                                  8826.0  Centre gauche à centre droit
#
#       Personnel médical  Autre sans internes  \
# 0              2.014903            -3.000000
# 1              3.491038             4.055084
# 2              0.623261             2.987448
# 3              5.028017             5.840133
# 4              3.386084             5.015888
# ...                 ...                  ...
# 1145           3.961955             4.574402
# 1146           2.422144             3.397189
# 1147           2.624669            -3.000000
# 1148           2.624669             4.384149
# 1149           4.328098             4.328362
#
#       Autre sans direction et administratif  \
# 0                                 -3.000000
# 1                                  3.597130
# 2                                  2.751110
# 3                                  6.040993
# 4                                  4.592996
# ...                                     ...
# 1145                               3.091951
# 1146                               1.990610
# 1147                              -3.000000
# 1148                               4.087488
# 1149                               2.695978
#
#       Autre sans techniques et ouvriers  Capital_tech  Médecins  \
# 0                             -3.000000      0.000000  1.504077
# 1                              3.442019     12.490326  2.917230
# 2                              1.851599     -3.000000  0.585005
# 3                              6.055108     13.769173  4.673763
# 4                              4.601865      2.079442  2.967847
# ...                                 ...           ...       ...
# 1145                           4.412919      2.079442  3.513335
# 1146                           3.291383     -3.000000  2.193886
# 1147                          -3.000000      1.945910  1.871802
# 1148                           4.247924     -3.000000  2.424803
# 1149                           4.245921     12.120831  3.535145
#
#       Autres_personnels_médicaux
# 0                       1.098612
# 1                       2.662355
# 2                      -2.659260
# 3                       3.818371
# 4                       2.312535
# ...                          ...
# 1145                    2.944439
# 1146                    0.832909
# 1147                    1.987874
# 1148                    0.916291
# 1149                    3.725693
#
# [1150 rows x 131 columns]

# %%
dfm.columns[:30]
# Out:
# Index(['Capital_Examens_biologiques x Capital_Examens_biologiques',
#        'Capital_Examens_biologiques x Capital_Bloc',
#        'Capital_Examens_biologiques x Autre sans techniques et ouvriers',
#        'Capital_Examens_biologiques x Autre sans direction et administratif',
#        'Capital_Examens_biologiques x Autre sans internes',
#        'Capital_imagerie x Capital_Examens_biologiques',
#        'Capital_imagerie x Capital_imagerie',
#        'Capital_imagerie x Capital_Bloc', 'Capital_imagerie x Capital_Lit_MCO',
#        'Capital_imagerie x Autre sans techniques et ouvriers',
#        'Capital_imagerie x Autre sans direction et administratif',
#        'Capital_imagerie x Autre sans internes', 'Capital_Bloc x Capital_Bloc',
#        'Capital_Bloc x Autre sans techniques et ouvriers',
#        'Capital_Bloc x Autre sans direction et administratif',
#        'Capital_Bloc x Autre sans internes',
#        'Capital_tech x Capital_Examens_biologiques',
#        'Capital_tech x Capital_imagerie', 'Capital_tech x Capital_Bloc',
#        'Capital_tech x Capital_tech', 'Capital_tech x Capital_Lit_MCO',
#        'Capital_tech x Autre sans techniques et ouvriers',
#        'Capital_tech x Autre sans direction et administratif',
#        'Capital_tech x Autre sans internes',
#        'Capital_Lit_MCO x Capital_Examens_biologiques',
#        'Capital_Lit_MCO x Capital_Bloc', 'Capital_Lit_MCO x Capital_Lit_MCO',
#        'Capital_Lit_MCO x Autre sans techniques et ouvriers',
#        'Capital_Lit_MCO x Autre sans direction et administratif',
#        'Capital_Lit_MCO x Autre sans internes'],
#       dtype='object')

# %% [markdown]
# ## 2. Justification du modèle choisi

# %% [markdown]
# ### 2.1 Le passage au log

# %% [markdown]
# On commence par vérifier que nos variables principales sont corrélées avec Y (la production en points ISA) log-linéairement plutôt que linéairement. On prend pour exemples trois facteurs de production essentielles : les médecins, le personnel de service de soins (notamment infirmier.ère.s) et le nombre de lits en MCO.

# %%
#Pour les médecins salariés, on enlève les valeurs nulles (transformé en log, ce sont les -infini que l'on a recodé en -3) 
# sinon elles baissent artificiellement la droite de régression et rend les graphes moins lisibles

#index_null = df[ df['Personnel Médical'] == 0 ].index
#index_null_log = df_log[ df_log['Personnel Médical'] == -3 ].index

#df_nnull = df.drop(index_null)
#df_log_nnull = df_log.drop(index_null_log)

sns.lmplot(x = 'Personnel médical', y = 'Points_ISA', data = df)
sns.lmplot(x = 'Personnel médical', y = 'Points_ISA', data = df_log)

# %%
sns.lmplot(x = 'Capital_Lit_MCO', y = 'Points_ISA', data = df)
sns.lmplot(x = 'Capital_Lit_MCO', y = 'Points_ISA', data = df_log)

# %%
sns.lmplot(x = 'Personnels des services de soins', y = 'Points_ISA', data = df)
sns.lmplot(x = 'Personnels des services de soins', y = 'Points_ISA', data = df_log)

# %% [markdown]
# Ces représentations graphiques et régressions montrent bien la pertinence du modèle translog puisque nos variables sont bien plus corrélées log-linéairement que linéairement.

# %% [markdown]
# ### 2.2 Comparaison entre un modèle de type Cobb-Douglas et un modèle translog

# %% [markdown]
# #### Premiers résultats généraux :

# %%
X = dfm[['Personnel médical', 'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 'Internes',  
        'Capital_Lit_MCO', 'Capital_imagerie', 'Capital_Bloc', 'Capital_Examens_biologiques']]
X = sm.add_constant(X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = dfm['Points_ISA']

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     619.7
# Date:                Tue, 11 May 2021   Prob (F-statistic):               0.00
# Time:                        17:26:42   Log-Likelihood:                -1114.1
# No. Observations:                1150   AIC:                             2254.
# Df Residuals:                    1137   BIC:                             2320.
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.5090      0.163     52.083      0.000       8.188       8.830
# Personnel médical                             0.1144      0.022      5.149      0.000       0.071       0.158
# Personnels de direction et administratifs     0.0459      0.042      1.092      0.275      -0.037       0.128
# Personnels des services de soins              0.1817      0.046      3.983      0.000       0.092       0.271
# Personnels éducatifs et sociaux              -0.0097      0.017     -0.578      0.563      -0.043       0.023
# Personnels médico-techniques                  0.0842      0.019      4.536      0.000       0.048       0.121
# Personnels techniques et ouvriers            -0.0587      0.020     -2.986      0.003      -0.097      -0.020
# Internes                                      0.0857      0.010      8.394      0.000       0.066       0.106
# Capital_Lit_MCO                               0.2828      0.018     15.331      0.000       0.247       0.319
# Capital_imagerie                              0.0341      0.011      3.018      0.003       0.012       0.056
# Capital_Bloc                                  0.2471      0.014     17.960      0.000       0.220       0.274
# Capital_Examens_biologiques                   0.0252      0.004      6.291      0.000       0.017       0.033
# stjr                                         -0.0014      0.033     -0.042      0.966      -0.066       0.063
# ==============================================================================
# Omnibus:                      150.833   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1306.443
# Skew:                          -0.263   Prob(JB):                    2.04e-284
# Kurtosis:                       8.195   Cond. No.                         90.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# On obtient des coefficients en grande majorité significatifs à 5%, on peut donc les interpréter.
#
# ATTENTION c'est une régression log-log donc les coefficients s'interprètent comme des % : 1% de Xi en plus augmente de beta(Xi)% la production.

# %% [markdown]
# On constate qu'avec autant de variables, le modèle translog n'est pas pertinent, les p-values élevées montrent que beaucoup de coefficients ne sont pas significatifs. On garde donc pour le moment le modèle simple.
# On souhaite à présent comparer ces variables entre les hôpitaux privés, publics et privés à but non lucratif.

# %%
# 1 public 2 privé lucratif 3 privé non lucratif

index_non_public = dfm[ dfm['stjr'] != 1].index
index_non_privé = dfm[ dfm['stjr'] != 2].index
index_non_pnl = dfm[ dfm['stjr'] != 3].index

dfm_public = dfm.drop(index_non_public)
dfm_privé = dfm.drop(index_non_privé)
dfm_pnl = dfm.drop(index_non_pnl)

# %%
print("Nombre d'hôpitaux publics : ", dfm_public['stjr'].count())
print("Nombre d'hôpitaux privés : ", dfm_privé['stjr'].count())
print("Nombre d'hôpitaux privés à but non lucratif : ", dfm_pnl['stjr'].count())
# Out:
# Nombre d'hôpitaux publics :  517
# Nombre d'hôpitaux privés :  461
# Nombre d'hôpitaux privés à but non lucratif :  172

# %%
# Régression sur les hôpitaux publics : 

X = dfm_public[['Personnel médical', 'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 'Internes', 
        'Capital_Lit_MCO', 'Capital_imagerie', 'Capital_Bloc', 'Capital_Examens_biologiques']]
X = sm.add_constant(X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = dfm_public['Points_ISA']

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     573.7
# Date:                Tue, 11 May 2021   Prob (F-statistic):          3.90e-277
# Time:                        17:35:52   Log-Likelihood:                -428.61
# No. Observations:                 517   AIC:                             881.2
# Df Residuals:                     505   BIC:                             932.2
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         7.6188      0.309     24.686      0.000       7.012       8.225
# Personnel médical                             0.0788      0.034      2.295      0.022       0.011       0.146
# Personnels de direction et administratifs    -0.1081      0.080     -1.353      0.177      -0.265       0.049
# Personnels des services de soins              0.0726      0.086      0.844      0.399      -0.096       0.241
# Personnels éducatifs et sociaux               0.0322      0.028      1.134      0.257      -0.024       0.088
# Personnels médico-techniques                  0.1481      0.043      3.459      0.001       0.064       0.232
# Personnels techniques et ouvriers            -0.0169      0.055     -0.308      0.758      -0.125       0.091
# Internes                                      0.0978      0.018      5.522      0.000       0.063       0.133
# Capital_Lit_MCO                               0.7010      0.039     18.077      0.000       0.625       0.777
# Capital_imagerie                              0.0713      0.025      2.912      0.004       0.023       0.119
# Capital_Bloc                                  0.1068      0.021      5.011      0.000       0.065       0.149
# Capital_Examens_biologiques                   0.0156      0.005      3.314      0.001       0.006       0.025
# ==============================================================================
# Omnibus:                       67.722   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              316.996
# Skew:                          -0.459   Prob(JB):                     1.46e-69
# Kurtosis:                       6.725   Cond. No.                         175.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Régression sur les hôpitaux privés

X = dfm_privé[['Personnel médical', 'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 'Internes', 
        'Capital_Lit_MCO', 'Capital_imagerie', 'Capital_Bloc', 'Capital_Examens_biologiques']]
X = sm.add_constant(X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = dfm_privé['Points_ISA']

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     178.9
# Date:                Tue, 11 May 2021   Prob (F-statistic):          2.38e-156
# Time:                        17:36:24   Log-Likelihood:                -367.17
# No. Observations:                 461   AIC:                             758.3
# Df Residuals:                     449   BIC:                             807.9
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         7.7170      0.224     34.399      0.000       7.276       8.158
# Personnel médical                             0.0605      0.030      2.026      0.043       0.002       0.119
# Personnels de direction et administratifs     0.3810      0.073      5.231      0.000       0.238       0.524
# Personnels des services de soins              0.2447      0.055      4.472      0.000       0.137       0.352
# Personnels éducatifs et sociaux              -0.0156      0.021     -0.740      0.459      -0.057       0.026
# Personnels médico-techniques                  0.0564      0.021      2.698      0.007       0.015       0.098
# Personnels techniques et ouvriers            -0.0343      0.022     -1.569      0.117      -0.077       0.009
# Internes                                      0.0170      0.017      1.031      0.303      -0.015       0.050
# Capital_Lit_MCO                               0.1013      0.023      4.311      0.000       0.055       0.147
# Capital_imagerie                             -0.0174      0.012     -1.434      0.152      -0.041       0.006
# Capital_Bloc                                  0.2877      0.022     12.841      0.000       0.244       0.332
# Capital_Examens_biologiques                   0.0113      0.010      1.080      0.281      -0.009       0.032
# ==============================================================================
# Omnibus:                      124.076   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1828.796
# Skew:                          -0.713   Prob(JB):                         0.00
# Kurtosis:                      12.653   Cond. No.                         82.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Régression sur les hôpitaux privés à but non lucratif

X = dfm_pnl[['Personnel médical', 'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 'Internes',
        'Capital_Lit_MCO', 'Capital_imagerie', 'Capital_Bloc', 'Capital_Examens_biologiques']]
X = sm.add_constant(X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = dfm_pnl['Points_ISA']

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     105.4
# Date:                Tue, 11 May 2021   Prob (F-statistic):           2.25e-67
# Time:                        17:36:43   Log-Likelihood:                -163.27
# No. Observations:                 172   AIC:                             350.5
# Df Residuals:                     160   BIC:                             388.3
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.0017      0.404     19.822      0.000       7.204       8.799
# Personnel médical                             0.2134      0.053      4.061      0.000       0.110       0.317
# Personnels de direction et administratifs    -0.0614      0.074     -0.832      0.407      -0.207       0.084
# Personnels des services de soins              0.3215      0.122      2.641      0.009       0.081       0.562
# Personnels éducatifs et sociaux              -0.0646      0.043     -1.495      0.137      -0.150       0.021
# Personnels médico-techniques                  0.0182      0.043      0.427      0.670      -0.066       0.102
# Personnels techniques et ouvriers            -0.0607      0.047     -1.304      0.194      -0.153       0.031
# Internes                                      0.0696      0.022      3.167      0.002       0.026       0.113
# Capital_Lit_MCO                               0.2963      0.037      8.017      0.000       0.223       0.369
# Capital_imagerie                              0.0694      0.031      2.269      0.025       0.009       0.130
# Capital_Bloc                                  0.2550      0.033      7.812      0.000       0.191       0.319
# Capital_Examens_biologiques                  -0.0070      0.011     -0.620      0.536      -0.029       0.015
# ==============================================================================
# Omnibus:                       17.493   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.437
# Skew:                          -0.675   Prob(JB):                     2.21e-05
# Kurtosis:                       4.081   Cond. No.                         77.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ATTENTION ces régressions ne sont pas très significatives, voir si on peut arranger avec d'autres variables !

# %% [markdown]
# BROUILLON

# %%
dfm.groupby('Bloc_politique').count()
# Out:
#                               Capital_tech x Capital_tech  \
# Bloc_politique
# Centre droit à droite                                 145
# Centre gauche à centre droit                          550
# Droite à extrême droite                               286
# Extrême gauche à gauche                               174
#
#                               Capital_tech x Autres_personnels_médicaux  \
# Bloc_politique
# Centre droit à droite                                               145
# Centre gauche à centre droit                                        550
# Droite à extrême droite                                             286
# Extrême gauche à gauche                                             174
#
#                               LIT_MCO x Capital_tech  LIT_MCO x LIT_MCO  \
# Bloc_politique
# Centre droit à droite                            145                145
# Centre gauche à centre droit                     550                550
# Droite à extrême droite                          286                286
# Extrême gauche à gauche                          174                174
#
#                               LIT_MCO x Internes  \
# Bloc_politique
# Centre droit à droite                        145
# Centre gauche à centre droit                 550
# Droite à extrême droite                      286
# Extrême gauche à gauche                      174
#
#                               LIT_MCO x Autres_personnels_médicaux  \
# Bloc_politique
# Centre droit à droite                                          145
# Centre gauche à centre droit                                   550
# Droite à extrême droite                                        286
# Extrême gauche à gauche                                        174
#
#                               Internes x Capital_tech  Internes x Internes  \
# Bloc_politique
# Centre droit à droite                             145                  145
# Centre gauche à centre droit                      550                  550
# Droite à extrême droite                           286                  286
# Extrême gauche à gauche                           174                  174
#
#                               Internes x Autres_personnels_médicaux  \
# Bloc_politique
# Centre droit à droite                                           145
# Centre gauche à centre droit                                    550
# Droite à extrême droite                                         286
# Extrême gauche à gauche                                         174
#
#                               Personnels techniques et ouvriers x Capital_tech  \
# Bloc_politique
# Centre droit à droite                                                      145
# Centre gauche à centre droit                                               550
# Droite à extrême droite                                                    286
# Extrême gauche à gauche                                                    174
#
#                               ...  Q1_B  Q1_C  Q1_D  Q8_A  Q8_B  Q8_C  Q8_D  \
# Bloc_politique                ...
# Centre droit à droite         ...   145   145   145   145   145   145   145
# Centre gauche à centre droit  ...   550   550   550   550   550   550   550
# Droite à extrême droite       ...   286   286   286   286   286   286   286
# Extrême gauche à gauche       ...   174   174   174   174   174   174   174
#
#                               Capital_tech  Médecins  \
# Bloc_politique
# Centre droit à droite                  145       145
# Centre gauche à centre droit           550       550
# Droite à extrême droite                286       286
# Extrême gauche à gauche                174       174
#
#                               Autres_personnels_médicaux
# Bloc_politique
# Centre droit à droite                                145
# Centre gauche à centre droit                         550
# Droite à extrême droite                              286
# Extrême gauche à gauche                              174
#
# [4 rows x 96 columns]

# %%
dfm.groupby('Bloc_politique').count()
index_g = dfm[ dfm['Bloc_politique'] == 'Droite à extrême droite'].index
index_g_bis = dfm[ dfm['Bloc_politique'] == 'Centre droit à droite'].index

dfm_gauche = dfm.drop(index_g)
dfm_g = dfm_gauche.drop(index_g_bis)

# %%
X = dfm_g[['Personnels des services de soins', 'Personnels de direction et administratifs',
        'LIT_MCO', 'Capital_Bloc', 'Capital_Examens_biologiques', 'Taux_chomage_par_dep']]
X = sm.add_constant(X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = dfm_g['Personnels médico-techniques']

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
results.params
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     Personnels médico-techniques   R-squared:                       0.702
# Model:                                      OLS   Adj. R-squared:                  0.700
# Method:                           Least Squares   F-statistic:                     281.8
# Date:                          Tue, 11 May 2021   Prob (F-statistic):          8.04e-185
# Time:                                  15:30:54   Log-Likelihood:                -1083.4
# No. Observations:                           724   AIC:                             2181.
# Df Residuals:                               717   BIC:                             2213.
# Df Model:                                     6
# Covariance Type:                      nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                        -3.3567      0.319    -10.537      0.000      -3.982      -2.731
# Personnels des services de soins              0.5345      0.094      5.658      0.000       0.349       0.720
# Personnels de direction et administratifs     0.5908      0.091      6.488      0.000       0.412       0.770
# LIT_MCO                                       0.1019      0.038      2.707      0.007       0.028       0.176
# Capital_Bloc                                  0.0242      0.025      0.966      0.334      -0.025       0.073
# Capital_Examens_biologiques                   0.0594      0.007      8.637      0.000       0.046       0.073
# Taux_chomage_par_dep                         -0.0080      0.026     -0.314      0.754      -0.058       0.042
# ==============================================================================
# Omnibus:                      292.969   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1588.374
# Skew:                          -1.754   Prob(JB):                         0.00
# Kurtosis:                       9.352   Cond. No.                         92.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# const                                       -3.356709
# Personnels des services de soins             0.534535
# Personnels de direction et administratifs    0.590766
# LIT_MCO                                      0.101897
# Capital_Bloc                                 0.024187
# Capital_Examens_biologiques                  0.059394
# Taux_chomage_par_dep                        -0.008047
# dtype: float64

# %%
df.columns
# Out:
# Index(['Numero_finess', 'Médecins libéraux',
#        'Autres personnels médicaux libéraux', 'Médecins salariés',
#        'Autres personnels médicaux salariés',
#        'Personnels de direction et administratifs',
#        'Personnels des services de soins', 'Personnels éducatifs et sociaux',
#        'Personnels médico-techniques', 'Personnels techniques et ouvriers',
#        'Points_ISA', 'stjr', 'Internes', 'dep', 'Departement', 'COMINSEE',
#        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
#        'Capital_Examens_biologiques', 'Capital_telemed', 'SEJHC_MED',
#        'SEJHC_CHI', 'SEJHC_OBS', 'SEJHC_MCO', 'Taux_chomage_par_dep',
#        'Population', 'Dep Moyenne Salaires Horaires',
#        'Dep Moyenne Salaires Cadre Horaires',
#        'Dep Moyenne Salaires Prof Intermédiaire Horaires',
#        'Dep Moyenne Salaires Employé Horaires',
#        'Moyenne Revenus Fiscaux Départementaux', 'Bloc_politique',
#        'Personnel médical', 'Autre sans internes',
#        'Autre sans direction et administratif',
#        'Autre sans techniques et ouvriers', 'Capital_tech', 'Médecins',
#        'Autres_personnels_médicaux'],
#       dtype='object')

# %%
X = dfm[['Personnel médical', 'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Autre sans direction et administratif',
        'Capital_Lit_MCO', 'Capital_tech',
        'Capital_tech x Capital_Lit_MCO',
       'Personnels des services de soins x Capital_tech',
       'Personnels des services de soins x Capital_Lit_MCO',
       'Personnels des services de soins x Personnels de direction et administratifs',
       'Personnels des services de soins x Personnel médical',
       'Personnels de direction et administratifs x Capital_tech',
       'Personnels de direction et administratifs x Capital_Lit_MCO',
       'Personnels de direction et administratifs x Personnel médical',
       'Personnel médical x Capital_tech', 'Personnel médical x Capital_Lit_MCO',
        'Capital_tech x Capital_tech', 'Capital_Lit_MCO x Capital_Lit_MCO',
        'Personnel médical x Personnel médical', 
        'Personnels de direction et administratifs x Personnels de direction et administratifs',
        'Personnels des services de soins x Personnels des services de soins',
        'Autre sans direction et administratif x Autre sans direction et administratif',
        'Personnels des services de soins x Autre sans direction et administratif',
        'Capital_tech x Autre sans direction et administratif',
        'Personnels de direction et administratifs x Autre sans direction et administratif',
        'Personnel médical x Autre sans direction et administratif',
        'Capital_Lit_MCO x Autre sans direction et administratif']]

X = sm.add_constant(X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = dfm['Points_ISA']

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     374.3
# Date:                Tue, 11 May 2021   Prob (F-statistic):               0.00
# Time:                        18:00:47   Log-Likelihood:                -951.39
# No. Observations:                1150   AIC:                             1959.
# Df Residuals:                    1122   BIC:                             2100.
# Df Model:                          27
# Covariance Type:            nonrobust
# =========================================================================================================================================================
#                                                                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                     7.0363      0.242     29.085      0.000       6.562       7.511
# Personnel médical                                                                         0.6675      0.092      7.283      0.000       0.488       0.847
# Personnels de direction et administratifs                                                -0.1316      0.113     -1.161      0.246      -0.354       0.091
# Personnels des services de soins                                                          0.0348      0.107      0.326      0.745      -0.175       0.244
# Autre sans direction et administratif                                                     0.1226      0.048      2.544      0.011       0.028       0.217
# Capital_Lit_MCO                                                                           0.1457      0.061      2.370      0.018       0.025       0.266
# Capital_tech                                                                              0.0839      0.030      2.778      0.006       0.025       0.143
# Capital_tech x Capital_Lit_MCO                                                           -0.0466      0.007     -7.156      0.000      -0.059      -0.034
# Personnels des services de soins x Capital_tech                                           0.0485      0.011      4.334      0.000       0.027       0.070
# Personnels des services de soins x Capital_Lit_MCO                                       -0.0316      0.021     -1.469      0.142      -0.074       0.011
# Personnels des services de soins x Personnels de direction et administratifs             -0.0125      0.041     -0.304      0.761      -0.093       0.068
# Personnels des services de soins x Personnel médical                                     -0.1168      0.029     -4.093      0.000      -0.173      -0.061
# Personnels de direction et administratifs x Capital_tech                                 -0.0341      0.010     -3.333      0.001      -0.054      -0.014
# Personnels de direction et administratifs x Capital_Lit_MCO                               0.0549      0.025      2.223      0.026       0.006       0.103
# Personnels de direction et administratifs x Personnel médical                            -0.0231      0.024     -0.964      0.335      -0.070       0.024
# Personnel médical x Capital_tech                                                          0.0068      0.008      0.904      0.366      -0.008       0.022
# Personnel médical x Capital_Lit_MCO                                                      -0.0111      0.011     -0.967      0.334      -0.033       0.011
# Capital_tech x Capital_tech                                                              -0.0004      0.001     -0.339      0.734      -0.003       0.002
# Capital_Lit_MCO x Capital_Lit_MCO                                                         0.0888      0.008     11.749      0.000       0.074       0.104
# Personnel médical x Personnel médical                                                     0.0665      0.009      7.433      0.000       0.049       0.084
# Personnels de direction et administratifs x Personnels de direction et administratifs     0.0244      0.017      1.404      0.161      -0.010       0.058
# Personnels des services de soins x Personnels des services de soins                       0.0432      0.021      2.045      0.041       0.002       0.085
# Autre sans direction et administratif x Autre sans direction et administratif             0.0279      0.005      5.562      0.000       0.018       0.038
# Personnels des services de soins x Autre sans direction et administratif                 -0.0512      0.016     -3.235      0.001      -0.082      -0.020
# Capital_tech x Autre sans direction et administratif                                     -0.0006      0.002     -0.269      0.788      -0.005       0.004
# Personnels de direction et administratifs x Autre sans direction et administratif        -0.0378      0.014     -2.657      0.008      -0.066      -0.010
# Personnel médical x Autre sans direction et administratif                                 0.0261      0.008      3.332      0.001       0.011       0.041
# Capital_Lit_MCO x Autre sans direction et administratif                                   0.0381      0.007      5.382      0.000       0.024       0.052
# ==============================================================================
# Omnibus:                      341.867   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2589.717
# Skew:                          -1.158   Prob(JB):                         0.00
# Kurtosis:                       9.977   Cond. No.                     2.17e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
results.params
# Out:
# const                                                                                    7.036347
# Personnel médical                                                                        0.667485
# Personnels de direction et administratifs                                               -0.131552
# Personnels des services de soins                                                         0.034772
# Autre sans direction et administratif                                                    0.122584
# Capital_Lit_MCO                                                                          0.145693
# Capital_tech                                                                             0.083907
# Capital_tech x Capital_Lit_MCO                                                          -0.046551
# Personnels des services de soins x Capital_tech                                          0.048466
# Personnels des services de soins x Capital_Lit_MCO                                      -0.031553
# Personnels des services de soins x Personnels de direction et administratifs            -0.012477
# Personnels des services de soins x Personnel médical                                    -0.116843
# Personnels de direction et administratifs x Capital_tech                                -0.034076
# Personnels de direction et administratifs x Capital_Lit_MCO                              0.054885
# Personnels de direction et administratifs x Personnel médical                           -0.023128
# Personnel médical x Capital_tech                                                         0.006836
# Personnel médical x Capital_Lit_MCO                                                     -0.011054
# Capital_tech x Capital_tech                                                             -0.000411
# Capital_Lit_MCO x Capital_Lit_MCO                                                        0.088755
# Personnel médical x Personnel médical                                                    0.066535
# Personnels de direction et administratifs x Personnels de direction et administratifs    0.024376
# Personnels des services de soins x Personnels des services de soins                      0.043222
# Autre sans direction et administratif x Autre sans direction et administratif            0.027887
# Personnels des services de soins x Autre sans direction et administratif                -0.051191
# Capital_tech x Autre sans direction et administratif                                    -0.000614
# Personnels de direction et administratifs x Autre sans direction et administratif       -0.037847
# Personnel médical x Autre sans direction et administratif                                0.026067
# Capital_Lit_MCO x Autre sans direction et administratif                                  0.038066
# dtype: float64

# %%
elasticite_med = results.params[1] + results.params[11] * dfm['Personnels des services de soins']
                + results.params[14] * df['Personnels de direction et administratifs']
                + results.params[15] * df['Capital_tech']
                + results.params[16] * df['Capital_Lit_MCO']
                + results.params[19] * df['Personnel médical'] * 2
                + results.params[26] * df['Autre sans direction et administratif']
                
el_captech = results.params[6] + results.params[7] * dfm['Capital_Lit_MCO']
                 + results.params[8] * dfm['Personnels des services de soins']
                  + results.params[12] * dfm['Personnels de direction et administratifs']
                  + results.params[15] * dfm['Personnel médical']
                  + results.params[17] * dfm['Capital_tech']
                  + results.params[24] * dfm['Autre sans direction et administratif']                
                
infl_med_captech = dfm['Points_ISA']/(dfm['Personnel médical']*dfm['Capital_tech']) * (results.params[15] 
            +(results.params[1] + results.params[11] * dfm['Personnels des services de soins']
                + results.params[14] * df['Personnels de direction et administratifs']
                + results.params[15] * df['Capital_tech']
                + results.params[16] * df['Capital_Lit_MCO']
                + results.params[19] * df['Personnel médical'] * 2
                + results.params[26] * df['Autre sans direction et administratif'])
                *(results.params[6] + results.params[7] * dfm['Capital_Lit_MCO']
                 + results.params[8] * dfm['Personnels des services de soins']
                  + results.params[12] * dfm['Personnels de direction et administratifs']
                  + results.params[15] * dfm['Personnel médical']
                  + results.params[17] * dfm['Capital_tech']
                  + results.params[24] * dfm['Autre sans direction et administratif']))
# Out:
#   File "<ipython-input-199-a41303d095be>", line 2
#     + results.params[14] * df['Personnels de direction et administratifs']
#     ^
# IndentationError: unexpected indent

# %%
df2 = df.assign(infl_med_captech = (dfm['Points_ISA']/(dfm['Personnel médical']*dfm['Capital_tech'])) * (results.params[15]
            + (results.params[1] + results.params[11] * dfm['Personnels des services de soins']
                + results.params[14] * dfm['Personnels de direction et administratifs']
                + results.params[15] * dfm['Capital_tech']
                + results.params[16] * dfm['Capital_Lit_MCO']
                + results.params[19] * dfm['Personnel médical']
                + results.params[26] * dfm['Autre sans direction et administratif'])
                *(results.params[6] + results.params[7] * dfm['Capital_Lit_MCO']
                 + results.params[8] * dfm['Personnels des services de soins']
                  + results.params[12] * dfm['Personnels de direction et administratifs']
                  + results.params[15] * dfm['Personnel médical']
                  + results.params[17] * dfm['Capital_tech']
                  + results.params[24] * dfm['Autre sans direction et administratif']))     )

df2['infl_med_captech']
# Out:
# 0            inf
# 1       0.002226
# 2      -0.169636
# 3      -0.001650
# 4       0.024291
#           ...
# 1145    0.010116
# 1146   -0.028245
# 1147    0.041596
# 1148   -0.058501
# 1149    0.002869
# Name: infl_med_captech, Length: 1150, dtype: float64

# %%
index_inf = df2[ df2['infl_med_captech'] == -inf].index
index_inf2 = df2[ df2['infl_med_captech'] == inf].index


test = df2.drop(index_inf)
test1 = test.drop(index_inf2)
test1['infl_med_captech'].mean()
# Out:
# 0.02695061393544854

# %%
df1 = df.assign(elasticite_med = results.params[1] + results.params[11] * dfm['Personnels des services de soins'] 
                + results.params[14] * dfm['Personnels de direction et administratifs'] + results.params[15] * dfm['Capital_tech']
                + results.params[16] * dfm['Capital_Lit_MCO'] + results.params[19] * dfm['Personnel médical'] *2
                + results.params[26] * dfm['Autre sans direction et administratif'])
df1['elasticite_med'].mean()
# Out:
# 0.4815999177626358
