# %% [markdown]
# # Application du modèle économétrique

# %% [markdown]
# Nous allons appliquer notre modèle translog aux différentes variables construites précédemment.
# Pour commencer, nous créons notre base contenant notre variable d'intérêt Y, les variables explicatives et les variables de contrôle.

# %%
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
VAR_EXPL = pd.read_excel('C:/Users/mille/OneDrive/Documents/ENSAE/2ème année/Stat App/VAR_EXPL.xlsx')
VAR_CTRL = pd.read_excel('C:/Users/mille/OneDrive/Documents/ENSAE/2ème année/Stat App/VAR_CTRL.xlsx')
VAR_CTRL
# Out:
#       Unnamed: 0 Numero_finess     Points_ISA  stjr dep COMINSEE  LIT_MCO  \
# 0              0     060000528  356892.030000     3  06    06088    128.0
# 1              1     060780947  174552.540000     3  06    06088    105.0
# 2              2     060791811  146432.633333     3  06    06088     91.0
# 3              3     060780442   22842.380000     2  06    06088     30.0
# 4              4     060780715  342051.171667     2  06    06088    256.0
# ...          ...           ...            ...   ...  ..      ...      ...
# 1190         469     570000141    7607.485000     1  57    57631     24.0
# 1191         637     640019220   75597.775000     2  64    64445    137.0
# 1192         640     640780862     413.120000     1  64    64445      0.0
# 1193         906     670020098    9344.040000     3  67    67482    120.0
# 1194        1194     980500003  384239.250000     1  9F    9F611    364.0
#
#       Capital_Bloc  Capital_imagerie  Capital_Examens_biologiques  ...  \
# 0              8.0               9.0                        909.0  ...
# 1              5.0               4.0                          0.0  ...
# 2              2.0               2.0                          0.0  ...
# 3              6.0               1.0                          0.0  ...
# 4             26.0              10.0                          0.0  ...
# ...            ...               ...                          ...  ...
# 1190           0.0               0.0                          0.0  ...
# 1191          19.0               0.0                          0.0  ...
# 1192           0.0               0.0                          0.0  ...
# 1193           3.0               0.0                          0.0  ...
# 1194           6.0               7.0                    1574514.0  ...
#
#       Taux_chomage_par_dep                Bloc_politique       Q1_A  \
# 0                      8.9         Centre droit à droite  70.000000
# 1                      8.9         Centre droit à droite  14.545455
# 2                      8.9         Centre droit à droite  14.545455
# 3                      8.9         Centre droit à droite  18.478261
# 4                      8.9         Centre droit à droite  18.478261
# ...                    ...                           ...        ...
# 1190                   8.2       Droite à extrême droite        NaN
# 1191                   7.0  Centre gauche à centre droit        NaN
# 1192                   7.0  Centre gauche à centre droit        NaN
# 1193                   7.1  Centre gauche à centre droit        NaN
# 1194                  30.0         Centre droit à droite        NaN
#
#            Q1_B       Q1_C       Q1_D       Q8_A       Q8_B       Q8_C Q8_D
# 0     30.000000        NaN        NaN  33.333333  28.571429  38.095238  NaN
# 1     38.181818  32.727273  14.545455  19.852941  21.323529  58.823529  NaN
# 2     38.181818  32.727273  14.545455  19.852941  21.323529  58.823529  NaN
# 3     41.304348  30.434783   9.782609  42.766296  19.236884  37.996820  NaN
# 4     41.304348  30.434783   9.782609  42.766296  19.236884  37.996820  NaN
# ...         ...        ...        ...        ...        ...        ...  ...
# 1190        NaN        NaN        NaN        NaN        NaN        NaN  NaN
# 1191        NaN        NaN        NaN        NaN        NaN        NaN  NaN
# 1192        NaN        NaN        NaN        NaN        NaN        NaN  NaN
# 1193        NaN        NaN        NaN        NaN        NaN        NaN  NaN
# 1194        NaN        NaN        NaN        NaN        NaN        NaN  NaN
#
# [1195 rows x 30 columns]

# %%
del VAR_EXPL['Unnamed: 0']

# %%
del VAR_CTRL['Unnamed: 0']

# %%
df = pd.merge(VAR_EXPL, VAR_CTRL)
df
# Out:
#      Numero_finess  Médecins libéraux  Autres personnels médicaux libéraux  \
# 0        010007300                4.5                                  3.0
# 1        010008407                0.0                                  0.0
# 2        010009132                0.0                                  0.0
# 3        010780054                4.5                                  1.0
# 4        010780062                0.0                                  0.0
# ...            ...                ...                                  ...
# 1150     950300301                2.0                                  0.5
# 1151     950300350                5.5                                  6.5
# 1152     950630012                0.0                                  0.0
# 1153     950807982               33.0                                 38.5
# 1154     970100012               18.0                                 12.0
#
#       Médecins salariés  Autres personnels médicaux salariés  \
# 0                 0.000                                 0.00
# 1                18.490                                14.33
# 2                 1.795                                 0.07
# 3               102.600                                44.53
# 4                19.450                                10.10
# ...                 ...                                  ...
# 1150              6.970                                 1.80
# 1151              1.000                                 0.80
# 1152             11.300                                 2.50
# 1153              1.300                                 3.00
# 1154              3.000                                 0.00
#
#       Personnels de direction et administratifs  \
# 0                                      2.250000
# 1                                     21.196667
# 2                                      4.175000
# 3                                    118.605000
# 4                                     58.450000
# ...                                         ...
# 1150                                  22.560000
# 1151                                   6.600000
# 1152                                  23.070000
# 1153                                  61.000000
# 1154                                  29.560000
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             4.200000                              NaN
# 1                            97.323333                         0.846667
# 2                            46.700000                         1.065000
# 3                           388.590000                         4.930000
# 4                           336.540000                         5.450000
# ...                                ...                              ...
# 1150                        103.560000                         1.380000
# 1151                         27.550000                              NaN
# 1152                        177.880000                        39.070000
# 1153                        288.230000                         1.130000
# 1154                        128.220000                              NaN
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  ...  \
# 0                              NaN                                NaN  ...
# 1                         9.206667                             26.440  ...
# 2                         1.130000                             13.465  ...
# 3                       107.660000                            112.630  ...
# 4                        29.320000                             57.570  ...
# ...                            ...                                ...  ...
# 1150                      2.940000                              3.000  ...
# 1151                      3.000000                              1.000  ...
# 1152                      5.330000                             12.700  ...
# 1153                      7.690000                              6.000  ...
# 1154                      5.990000                             21.910  ...
#
#       Taux_chomage_par_dep                Bloc_politique       Q1_A  \
# 0                      6.1  Centre gauche à centre droit  18.478261
# 1                      6.1       Droite à extrême droite   2.898551
# 2                      6.1       Droite à extrême droite   2.898551
# 3                      6.1         Centre droit à droite   2.898551
# 4                      6.1  Centre gauche à centre droit   2.898551
# ...                    ...                           ...        ...
# 1150                   8.5       Extrême gauche à gauche  18.478261
# 1151                   8.5  Centre gauche à centre droit  18.478261
# 1152                   8.5  Centre gauche à centre droit  14.545455
# 1153                   8.5  Centre gauche à centre droit  18.478261
# 1154                  20.5  Centre gauche à centre droit  18.478261
#
#            Q1_B       Q1_C       Q1_D       Q8_A       Q8_B       Q8_C  Q8_D
# 0     41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# 2     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# 3     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# 4     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# ...         ...        ...        ...        ...        ...        ...   ...
# 1150  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1151  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1152  38.181818  32.727273  14.545455  19.852941  21.323529  58.823529   NaN
# 1153  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1154  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
#
# [1155 rows x 39 columns]

# %% [markdown]
# On obtient bien 1154 établissements, le nombre d'établissements qui avaient des données dans les bases du personnel. On n'a donc pas pris en compte les établissements présents dans la base des variables explicatives mais dont on ne pouvait rien dire, faute de données sur leur personnel.

# %%
df.columns
# Out:
# Index(['Numero_finess', 'Médecins libéraux',
#        'Autres personnels médicaux libéraux', 'Médecins salariés',
#        'Autres personnels médicaux salariés',
#        'Personnels de direction et administratifs',
#        'Personnels des services de soins', 'Personnels éducatifs et sociaux',
#        'Personnels médico-techniques', 'Personnels techniques et ouvriers',
#        'Points_ISA', 'stjr', 'Internes', 'dep', 'COMINSEE', 'LIT_MCO',
#        'Capital_Bloc', 'Capital_imagerie', 'Capital_Examens_biologiques',
#        'Capital_telemed', 'SEJHC_MED', 'SEJHC_CHI', 'SEJHC_OBS', 'SEJHC_MCO',
#        'JOU_MED', 'JOU_CHI', 'JOU_OBS', 'JOU_MCO', 'Departement',
#        'Taux_chomage_par_dep', 'Bloc_politique', 'Q1_A', 'Q1_B', 'Q1_C',
#        'Q1_D', 'Q8_A', 'Q8_B', 'Q8_C', 'Q8_D'],
#       dtype='object')

# %%
#Nous passons en log tous les variables que l'on va utiliser comme facteur de production dans notre fonction translog

df_log = df.apply(lambda x: np.log(x) if x.name in ['Médecins libéraux', 'Autres personnels médicaux libéraux', 
                                                    'Médecins salariés', 'Autres personnels médicaux salariés',
                                                    'Personnels de direction et administratifs',
                                                    'Personnels des services de soins', 'Personnels éducatifs et sociaux',
                                                    'Personnels médico-techniques', 'Personnels techniques et ouvriers',
                                                    'Points_ISA', 'Internes', 'LIT_MCO',
                                                    'Capital_Bloc', 'Capital_imagerie', 'Capital_Examens_biologiques',
                                                    'Capital_telemed'] else x)

from numpy import inf
df_log = df_log.replace(-inf, 0)

df_log
# Out:
#      Numero_finess  Médecins libéraux  Autres personnels médicaux libéraux  \
# 0        010007300           1.504077                             1.098612
# 1        010008407           0.000000                             0.000000
# 2        010009132           0.000000                             0.000000
# 3        010780054           1.504077                             0.000000
# 4        010780062           0.000000                             0.000000
# ...            ...                ...                                  ...
# 1150     950300301           0.693147                            -0.693147
# 1151     950300350           1.704748                             1.871802
# 1152     950630012           0.000000                             0.000000
# 1153     950807982           3.496508                             3.650658
# 1154     970100012           2.890372                             2.484907
#
#       Médecins salariés  Autres personnels médicaux salariés  \
# 0              0.000000                             0.000000
# 1              2.917230                             2.662355
# 2              0.585005                            -2.659260
# 3              4.630838                             3.796163
# 4              2.967847                             2.312535
# ...                 ...                                  ...
# 1150           1.941615                             0.587787
# 1151           0.000000                            -0.223144
# 1152           2.424803                             0.916291
# 1153           0.262364                             1.098612
# 1154           1.098612                             0.000000
#
#       Personnels de direction et administratifs  \
# 0                                      0.810930
# 1                                      3.053844
# 2                                      1.429114
# 3                                      4.775799
# 4                                      4.068172
# ...                                         ...
# 1150                                   3.116178
# 1151                                   1.887070
# 1152                                   3.138533
# 1153                                   4.110874
# 1154                                   3.386422
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             1.435085                              NaN
# 1                             4.578039                        -0.166448
# 2                             3.843744                         0.062975
# 3                             5.962525                         1.595339
# 4                             5.818717                         1.695616
# ...                                ...                              ...
# 1150                          4.640151                         0.322083
# 1151                          3.316003                              NaN
# 1152                          5.181109                         3.665355
# 1153                          5.663759                         0.122218
# 1154                          4.853748                              NaN
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  ...  \
# 0                              NaN                                NaN  ...
# 1                         2.219928                           3.274878  ...
# 2                         0.122218                           2.600094  ...
# 3                         4.678978                           4.724108  ...
# 4                         3.378270                           4.053002  ...
# ...                            ...                                ...  ...
# 1150                      1.078410                           1.098612  ...
# 1151                      1.098612                           0.000000  ...
# 1152                      1.673351                           2.541602  ...
# 1153                      2.039921                           1.791759  ...
# 1154                      1.790091                           3.086943  ...
#
#       Taux_chomage_par_dep                Bloc_politique       Q1_A  \
# 0                      6.1  Centre gauche à centre droit  18.478261
# 1                      6.1       Droite à extrême droite   2.898551
# 2                      6.1       Droite à extrême droite   2.898551
# 3                      6.1         Centre droit à droite   2.898551
# 4                      6.1  Centre gauche à centre droit   2.898551
# ...                    ...                           ...        ...
# 1150                   8.5       Extrême gauche à gauche  18.478261
# 1151                   8.5  Centre gauche à centre droit  18.478261
# 1152                   8.5  Centre gauche à centre droit  14.545455
# 1153                   8.5  Centre gauche à centre droit  18.478261
# 1154                  20.5  Centre gauche à centre droit  18.478261
#
#            Q1_B       Q1_C       Q1_D       Q8_A       Q8_B       Q8_C  Q8_D
# 0     41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# 2     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# 3     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# 4     14.975845  48.309179  33.816425   6.018519  10.339506  83.641975   NaN
# ...         ...        ...        ...        ...        ...        ...   ...
# 1150  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1151  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1152  38.181818  32.727273  14.545455  19.852941  21.323529  58.823529   NaN
# 1153  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
# 1154  41.304348  30.434783   9.782609  42.766296  19.236884  37.996820   NaN
#
# [1155 rows x 39 columns]

# %%
df_log['Points_ISA']
# Out:
# 0        8.239055
# 1       12.014033
# 2        8.650879
# 3       13.577163
# 4       12.145127
#           ...
# 1150     8.821722
# 1151     9.314645
# 1152     9.948997
# 1153    12.085705
# 1154    11.169588
# Name: Points_ISA, Length: 1155, dtype: float64

# %%
indexNames = df[ df['Médecins salariés'] == 0 ].index
indexNames1 = df_log[ df_log['Médecins salariés'] == 0 ].index
# Delete these row indexes from dataFrame
test = df.drop(indexNames)
test1 = df_log.drop(indexNames1)

sns.lmplot(x = 'Médecins salariés', y = 'Points_ISA', data = test, fit_reg = True)
sns.lmplot(x = 'Médecins salariés', y = 'Points_ISA', data = test1)

# %%
lre = scipy.stats.linregress(test['LIT_MCO'], test['Points_ISA'])
type(test['LIT_MCO'][5])
# Out:
# numpy.float64

# %%
test['LIT_MCO']
# Out:
# 1       102.0
# 2        10.0
# 3       369.0
# 4        93.0
# 5        59.0
#         ...
# 1150     21.0
# 1151     24.0
# 1152      5.0
# 1153    119.0
# 1154     92.0
# Name: LIT_MCO, Length: 936, dtype: float64
