# %% [markdown]
# # Etude de plusieurs facteurs environnementaux sur la production dans les hôpitaux

# %%
# importation des packages
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
VAR_CTRL = pd.read_csv('https://raw.githubusercontent.com/VincianeDesbois/Hopitaux_Production/main/Variables_controle.csv',  sep = ',')
VAR_EXPL_CAT  = pd.read_csv('https://raw.githubusercontent.com/VincianeDesbois/Hopitaux_Production/main/VAR_EXPL_CAT.csv',  sep = ',')

# %% [markdown]
# # Première analyse sur l'effet du revenu fiscal moyen sur les points ISA

# %%
VAR_EXPL_CAT_1 = VAR_EXPL_CAT[['Numero_finess', 'Personnel médical','stjr',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes']]
VAR_EXPL_CAT_1= VAR_EXPL_CAT_1.fillna(0)

# %%
VAR_EXPL_CAT_1
# Out:
#      Numero_finess  Personnel médical  stjr  \
# 0        010007300              7.500     2
# 1        010008407             32.820     1
# 2        010009132              1.865     1
# 3        010780054            152.630     1
# 4        010780062             29.550     1
# ...            ...                ...   ...
# 1147     950300277             52.560     2
# 1148     950300301             11.270     2
# 1149     950300350             13.800     2
# 1150     950630012             13.800     3
# 1151     950807982             75.800     2
#
#       Personnels de direction et administratifs  \
# 0                                      2.250000
# 1                                     21.196667
# 2                                      4.175000
# 3                                    118.605000
# 4                                     58.450000
# ...                                         ...
# 1147                                  74.950000
# 1148                                  22.560000
# 1149                                   6.600000
# 1150                                  23.070000
# 1151                                  61.000000
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             4.200000                         0.000000
# 1                            97.323333                         0.846667
# 2                            46.700000                         1.065000
# 3                           388.590000                         4.930000
# 4                           336.540000                         5.450000
# ...                                ...                              ...
# 1147                        246.990000                         1.100000
# 1148                        103.560000                         1.380000
# 1149                         27.550000                         0.000000
# 1150                        177.880000                        39.070000
# 1151                        288.230000                         1.130000
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                         0.000000                              0.000
# 1                         9.206667                             26.440
# 2                         1.130000                             13.465
# 3                       107.660000                            112.630
# 4                        29.320000                             57.570
# ...                            ...                                ...
# 1147                      6.460000                             14.460
# 1148                      2.940000                              3.000
# 1149                      3.000000                              1.000
# 1150                      5.330000                             12.700
# 1151                      7.690000                              6.000
#
#       Internes
# 0         0.00
# 1         0.00
# 2         0.00
# 3       195.09
# 4         6.45
# ...        ...
# 1147      0.00
# 1148      0.00
# 1149      0.00
# 1150      2.49
# 1151      0.00
#
# [1152 rows x 9 columns]

# %%
VAR_EXPL_CAT_1 = VAR_EXPL_CAT_1.apply(lambda x: np.log(x) if x.name in ['Personnel médical',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_EXPL_CAT_1 = VAR_EXPL_CAT_1.replace(-inf, -3)

VAR_EXPL_CAT_1
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Numero_finess  Personnel médical  stjr  \
# 0        010007300           2.014903     2
# 1        010008407           3.491038     1
# 2        010009132           0.623261     1
# 3        010780054           5.028017     1
# 4        010780062           3.386084     1
# ...            ...                ...   ...
# 1147     950300277           3.961955     2
# 1148     950300301           2.422144     2
# 1149     950300350           2.624669     2
# 1150     950630012           2.624669     3
# 1151     950807982           4.328098     2
#
#       Personnels de direction et administratifs  \
# 0                                      0.810930
# 1                                      3.053844
# 2                                      1.429114
# 3                                      4.775799
# 4                                      4.068172
# ...                                         ...
# 1147                                   4.316821
# 1148                                   3.116178
# 1149                                   1.887070
# 1150                                   3.138533
# 1151                                   4.110874
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             1.435085                        -3.000000
# 1                             4.578039                        -0.166448
# 2                             3.843744                         0.062975
# 3                             5.962525                         1.595339
# 4                             5.818717                         1.695616
# ...                                ...                              ...
# 1147                          5.509348                         0.095310
# 1148                          4.640151                         0.322083
# 1149                          3.316003                        -3.000000
# 1150                          5.181109                         3.665355
# 1151                          5.663759                         0.122218
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        -3.000000                          -3.000000
# 1                         2.219928                           3.274878
# 2                         0.122218                           2.600094
# 3                         4.678978                           4.724108
# 4                         3.378270                           4.053002
# ...                            ...                                ...
# 1147                      1.865629                           2.671386
# 1148                      1.078410                           1.098612
# 1149                      1.098612                           0.000000
# 1150                      1.673351                           2.541602
# 1151                      2.039921                           1.791759
#
#       Internes
# 0    -3.000000
# 1    -3.000000
# 2    -3.000000
# 3     5.273461
# 4     1.864080
# ...        ...
# 1147 -3.000000
# 1148 -3.000000
# 1149 -3.000000
# 1150  0.912283
# 1151 -3.000000
#
# [1152 rows x 9 columns]

# %%
VAR_CTRL.columns
#Je prends Cpaital_LIT_MCO et Capital_Bloc
# Out:
# Index(['Numero_finess', 'Points_ISA', 'stjr', 'dep', 'Departement', 'COMINSEE',
#        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
#        'Capital_Examens_biologiques', 'Capital_telemed', 'SEJHC_MED',
#        'SEJHC_CHI', 'SEJHC_OBS', 'SEJHC_MCO', 'Taux_chomage_par_dep',
#        'Population', 'Dep Moyenne Salaires Horaires',
#        'Dep Moyenne Salaires Cadre Horaires',
#        'Dep Moyenne Salaires Prof Intermédiaire Horaires',
#        'Dep Moyenne Salaires Employé Horaires',
#        'Moyenne Revenus Fiscaux Départementaux', 'Bloc_politique'],
#       dtype='object')

# %%
VAR_CTRL_1 = VAR_CTRL.copy()

VAR_CTRL_1 = VAR_CTRL_1.apply(lambda x: np.log(x) if x.name in ['Points_ISA', 'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed', 'Population'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_CTRL_1 = VAR_CTRL_1.replace(-inf, -3)

VAR_CTRL_1
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Numero_finess  Points_ISA  stjr dep      Departement COMINSEE  \
# 0        060000528   12.785189     3  06  Alpes-Maritimes    06088
# 1        060780947   12.069981     3  06  Alpes-Maritimes    06088
# 2        060791811   11.894321     3  06  Alpes-Maritimes    06088
# 3        060780442   10.036373     2  06  Alpes-Maritimes    06088
# 4        060780715   12.742716     2  06  Alpes-Maritimes    06088
# ...            ...         ...   ...  ..              ...      ...
# 1157     120780085   10.729103     1  12          Aveyron    12089
# 1158     480780097   12.391985     1  48           Lozère    48095
# 1159     480780162    8.648072     1  48           Lozère    48080
# 1160     480780121    7.781744     1  48           Lozère    48140
# 1161     480780154    6.249357     1  48           Lozère    48092
#
#       Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  \
# 0            4.852030      2.079442          2.197225
# 1            4.653960      1.609438          1.386294
# 2            4.510860      0.693147          0.693147
# 3            3.401197      1.791759          0.000000
# 4            5.545177      3.258097          2.302585
# ...               ...           ...               ...
# 1157         3.526361      1.609438          1.098612
# 1158         4.204693      1.504077          1.791759
# 1159         3.135494     -3.000000          0.000000
# 1160         3.091042     -3.000000         -3.000000
# 1161         2.995732     -3.000000         -3.000000
#
#       Capital_Examens_biologiques  ...  SEJHC_OBS  SEJHC_MCO  \
# 0                        6.812345  ...        0.0     7020.0
# 1                       -3.000000  ...        0.0     9754.0
# 2                       -3.000000  ...        0.0     2558.0
# 3                       -3.000000  ...        0.0     1605.0
# 4                       -3.000000  ...     1467.0    15866.0
# ...                           ...  ...        ...        ...
# 1157                    12.367630  ...        0.0     2056.0
# 1158                    12.956158  ...      392.0     3599.5
# 1159                    -3.000000  ...        0.0      421.0
# 1160                    -3.000000  ...        0.0      205.0
# 1161                    -3.000000  ...        0.0      384.0
#
#       Taux_chomage_par_dep  Population  Dep Moyenne Salaires Horaires  \
# 0                      8.9   12.745844                      12.579245
# 1                      8.9   12.745844                      12.579245
# 2                      8.9   12.745844                      12.579245
# 3                      8.9   12.745844                      12.579245
# 4                      8.9   12.745844                      12.579245
# ...                    ...         ...                            ...
# 1157                   6.4    8.822764                      10.115789
# 1158                   5.3    9.375177                      10.075000
# 1159                   5.3    8.038189                      10.075000
# 1160                   5.3    8.370779                      10.075000
# 1161                   5.3    8.613230                      10.075000
#
#       Dep Moyenne Salaires Cadre Horaires  \
# 0                               22.518868
# 1                               22.518868
# 2                               22.518868
# 3                               22.518868
# 4                               22.518868
# ...                                   ...
# 1157                            20.252632
# 1158                            20.475000
# 1159                            20.475000
# 1160                            20.475000
# 1161                            20.475000
#
#       Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                            12.864151
# 1                                            12.864151
# 2                                            12.864151
# 3                                            12.864151
# 4                                            12.864151
# ...                                                ...
# 1157                                         11.963158
# 1158                                         11.775000
# 1159                                         11.775000
# 1160                                         11.775000
# 1161                                         11.775000
#
#       Dep Moyenne Salaires Employé Horaires  \
# 0                                  8.835849
# 1                                  8.835849
# 2                                  8.835849
# 3                                  8.835849
# 4                                  8.835849
# ...                                     ...
# 1157                               8.478947
# 1158                               8.600000
# 1159                               8.600000
# 1160                               8.600000
# 1161                               8.600000
#
#       Moyenne Revenus Fiscaux Départementaux                Bloc_politique
# 0                                    12288.0         Centre droit à droite
# 1                                    12288.0         Centre droit à droite
# 2                                    12288.0         Centre droit à droite
# 3                                    12288.0         Centre droit à droite
# 4                                    12288.0         Centre droit à droite
# ...                                      ...                           ...
# 1157                                  9936.0       Extrême gauche à gauche
# 1158                                  8555.0  Centre gauche à centre droit
# 1159                                  8555.0  Centre gauche à centre droit
# 1160                                  8555.0         Centre droit à droite
# 1161                                  8555.0         Centre droit à droite
#
# [1162 rows x 23 columns]

# %%
VAR_CTRL.describe()
# Out:
#          Points_ISA         stjr  Capital_Lit_MCO  Capital_Bloc  \
# count  1.162000e+03  1162.000000      1139.000000   1153.000000
# mean   2.939915e+05     1.707401       125.109263      7.379577
# std    6.281782e+05     0.716795       127.684194      7.191520
# min    1.347900e+02     1.000000         0.000000      0.000000
# 25%    2.993899e+04     1.000000        35.000000      1.000000
# 50%    1.016205e+05     2.000000        85.000000      6.000000
# 75%    2.975944e+05     2.000000       171.166667     10.500000
# max    9.116903e+06     3.000000      1055.000000     44.000000
#
#        Capital_imagerie  Capital_Examens_biologiques  Capital_telemed  \
# count       1162.000000                 1.149000e+03      1162.000000
# mean           4.256971                 2.508881e+05         0.728148
# std            5.047103                 6.567670e+05         1.514649
# min            0.000000                 0.000000e+00         0.000000
# 25%            0.000000                 0.000000e+00         0.000000
# 50%            3.000000                 0.000000e+00         0.000000
# 75%            7.000000                 6.261400e+04         1.000000
# max           28.000000                 1.060114e+07        11.000000
#
#           SEJHC_MED     SEJHC_CHI    SEJHC_OBS     SEJHC_MCO  \
# count   1162.000000   1162.000000  1161.000000   1162.000000
# mean    3953.236728   2091.528256   673.093714   6717.279443
# std     5172.505167   2471.292213  1146.876402   7600.700172
# min        0.000000      0.000000     0.000000      0.000000
# 25%      364.750000      0.000000     0.000000   1204.500000
# 50%     1963.000000   1428.000000     0.000000   4168.500000
# 75%     5581.250000   3168.312500  1081.000000   9749.750000
# max    39884.000000  20991.000000  7639.000000  60719.000000
#
#        Taux_chomage_par_dep    Population  Dep Moyenne Salaires Horaires  \
# count           1162.000000  1.162000e+03                    1162.000000
# mean               8.290103  1.367009e+05                      11.793749
# std                1.660836  3.998901e+05                       1.908702
# min                5.000000  1.820000e+02                       9.862500
# 25%                7.000000  8.053750e+03                      10.633333
# 50%                8.000000  2.295500e+04                      11.204762
# 75%                9.300000  6.171825e+04                      11.981429
# max               13.800000  2.125851e+06                      17.800000
#
#        Dep Moyenne Salaires Cadre Horaires  \
# count                          1162.000000
# mean                             21.764363
# std                               1.674054
# min                              19.750000
# 25%                              20.775000
# 50%                              21.280808
# 75%                              22.083750
# max                              27.600000
#
#        Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# count                                       1162.000000
# mean                                          12.674821
# std                                            0.523229
# min                                           11.740000
# 25%                                           12.346721
# 50%                                           12.535714
# 75%                                           12.902500
# max                                           14.185000
#
#        Dep Moyenne Salaires Employé Horaires  \
# count                            1162.000000
# mean                                8.783985
# std                                 0.353571
# min                                 8.261905
# 25%                                 8.555172
# 50%                                 8.700862
# 75%                                 8.848113
# max                                 9.742553
#
#        Moyenne Revenus Fiscaux Départementaux
# count                             1162.000000
# mean                             10648.398451
# std                               2063.805307
# min                               6282.000000
# 25%                               9471.000000
# 50%                              10239.000000
# 75%                              11515.000000
# max                              16895.000000

# %% [markdown]
# Le premier quartile des revenus fiscaux moyens par mois est à 9471, et le troisième quartile à 11536. On sépare en deux bases : celles avec les départements avec les plus faibles revenus, et celles avec les départements avec les plus hauts revenus.

# %%
# Les établissements avec des revenus départements  trés élevés

VAR_CTRL_ELEVES = VAR_CTRL_1.copy()
VAR_CTRL_ELEVES= VAR_CTRL_ELEVES.rename(columns = {'Moyenne Revenus Fiscaux Départementaux': 'Rev_dep'})

VAR_CTRL_ELEVES= VAR_CTRL_ELEVES[VAR_CTRL_ELEVES.Rev_dep >= 11536]

# %%
# Les établissements avec des revenus départements trésfaibles

VAR_CTRL_FAIBLES = VAR_CTRL_1.copy()
VAR_CTRL_FAIBLES = VAR_CTRL_FAIBLES.rename(columns = {'Moyenne Revenus Fiscaux Départementaux': 'Rev_dep'})

VAR_CTRL_FAIBLES = VAR_CTRL_FAIBLES[VAR_CTRL_FAIBLES.Rev_dep <= 9471]

# %%
VAR_CTRL_FAIBLES
# Out:
#      Numero_finess  Points_ISA  stjr dep      Departement COMINSEE  \
# 89       350002812   11.019027     3  35  Ille-et-Vilaine    35238
# 90       350002192   12.499743     3  35  Ille-et-Vilaine    35238
# 91       350002200    9.658084     3  35  Ille-et-Vilaine    35238
# 92       350000139   12.581770     3  35  Ille-et-Vilaine    35238
# 93       350005179   15.037342     1  35  Ille-et-Vilaine    35238
# ...            ...         ...   ...  ..              ...      ...
# 1115     240000109    8.536630     1  24         Dordogne    24311
# 1158     480780097   12.391985     1  48           Lozère    48095
# 1159     480780162    8.648072     1  48           Lozère    48080
# 1160     480780121    7.781744     1  48           Lozère    48140
# 1161     480780154    6.249357     1  48           Lozère    48092
#
#       Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  \
# 89           3.988984      1.386294          2.197225
# 90           5.267858      2.397895          1.386294
# 91           1.945910     -3.000000          0.000000
# 92           4.962845      2.708050         -3.000000
# 93           5.771441      3.417727          2.564949
# ...               ...           ...               ...
# 1115         1.386294     -3.000000         -3.000000
# 1158         4.204693      1.504077          1.791759
# 1159         3.135494     -3.000000          0.000000
# 1160         3.091042     -3.000000         -3.000000
# 1161         2.995732     -3.000000         -3.000000
#
#       Capital_Examens_biologiques  ...  SEJHC_OBS  SEJHC_MCO  \
# 89                      11.852429  ...       0.00    2609.00
# 90                      -3.000000  ...       0.00   10701.00
# 91                      -3.000000  ...       0.00     276.00
# 92                      -3.000000  ...    4960.00    9592.00
# 93                      14.424276  ...    1461.75   17740.75
# ...                           ...  ...        ...        ...
# 1115                    -3.000000  ...       0.00     142.00
# 1158                    12.956158  ...     392.00    3599.50
# 1159                    -3.000000  ...       0.00     421.00
# 1160                    -3.000000  ...       0.00     205.00
# 1161                    -3.000000  ...       0.00     384.00
#
#       Taux_chomage_par_dep  Population  Dep Moyenne Salaires Horaires  \
# 89                     6.4   12.236573                      11.434091
# 90                     6.4   12.236573                      11.434091
# 91                     6.4   12.236573                      11.434091
# 92                     6.4   12.236573                      11.434091
# 93                     6.4   12.236573                      11.434091
# ...                    ...         ...                            ...
# 1115                   8.7    8.159947                      10.264516
# 1158                   5.3    9.375177                      10.075000
# 1159                   5.3    8.038189                      10.075000
# 1160                   5.3    8.370779                      10.075000
# 1161                   5.3    8.613230                      10.075000
#
#       Dep Moyenne Salaires Cadre Horaires  \
# 89                              20.478409
# 90                              20.478409
# 91                              20.478409
# 92                              20.478409
# 93                              20.478409
# ...                                   ...
# 1115                            20.806452
# 1158                            20.475000
# 1159                            20.475000
# 1160                            20.475000
# 1161                            20.475000
#
#       Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 89                                           12.553409
# 90                                           12.553409
# 91                                           12.553409
# 92                                           12.553409
# 93                                           12.553409
# ...                                                ...
# 1115                                         12.219355
# 1158                                         11.775000
# 1159                                         11.775000
# 1160                                         11.775000
# 1161                                         11.775000
#
#       Dep Moyenne Salaires Employé Horaires  Rev_dep  \
# 89                                 8.819318   9401.0
# 90                                 8.819318   9401.0
# 91                                 8.819318   9401.0
# 92                                 8.819318   9401.0
# 93                                 8.819318   9401.0
# ...                                     ...      ...
# 1115                               8.580645   7819.0
# 1158                               8.600000   8555.0
# 1159                               8.600000   8555.0
# 1160                               8.600000   8555.0
# 1161                               8.600000   8555.0
#
#                     Bloc_politique
# 89    Centre gauche à centre droit
# 90    Centre gauche à centre droit
# 91    Centre gauche à centre droit
# 92    Centre gauche à centre droit
# 93    Centre gauche à centre droit
# ...                            ...
# 1115  Centre gauche à centre droit
# 1158  Centre gauche à centre droit
# 1159  Centre gauche à centre droit
# 1160         Centre droit à droite
# 1161         Centre droit à droite
#
# [300 rows x 23 columns]

# %%
VAR_CTRL_FAIBLES= VAR_CTRL_FAIBLES.fillna(0)
VAR_CTRL_ELEVES= VAR_CTRL_ELEVES.fillna(0)
#stjr_1 = stjr_1.fillna(0)

# %%
analyse_dep_faibles = pd.merge(VAR_CTRL_FAIBLES, VAR_EXPL_CAT_1)

analyse_dep_eleves = pd.merge(VAR_CTRL_ELEVES, VAR_EXPL_CAT_1)

# %%
analyse_dep_faibles.columns
# Out:
# Index(['Numero_finess', 'Points_ISA', 'stjr', 'dep', 'Departement', 'COMINSEE',
#        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
#        'Capital_Examens_biologiques', 'Capital_telemed', 'SEJHC_MED',
#        'SEJHC_CHI', 'SEJHC_OBS', 'SEJHC_MCO', 'Taux_chomage_par_dep',
#        'Population', 'Dep Moyenne Salaires Horaires',
#        'Dep Moyenne Salaires Cadre Horaires',
#        'Dep Moyenne Salaires Prof Intermédiaire Horaires',
#        'Dep Moyenne Salaires Employé Horaires', 'Rev_dep', 'Bloc_politique',
#        'Personnel médical', 'Personnels de direction et administratifs',
#        'Personnels des services de soins', 'Personnels éducatifs et sociaux',
#        'Personnels médico-techniques', 'Personnels techniques et ouvriers',
#        'Internes'],
#       dtype='object')

# %%
analyse_dep_faibles_X =analyse_dep_faibles[["Personnel médical","Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie', 'Population',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_dep_faibles_Y =analyse_dep_faibles[['Points_ISA']]
analyse_dep_eleves_X =analyse_dep_eleves[["Personnel médical","Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
       'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie', 'Population',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_dep_eleves_Y =analyse_dep_eleves[['Points_ISA']]

# %%
analyse_dep_faibles_X
# Out:
#      Personnel médical  Internes  Personnels de direction et administratifs  \
# 0             3.952397  4.276666                                   4.582413
# 1             4.233962  3.044522                                   4.114964
# 2             2.634045  1.118415                                   3.226447
# 3             3.990834  2.890372                                   4.515245
# 4             5.745977  6.449751                                   5.208488
# ..                 ...       ...                                        ...
# 293           0.955511 -3.000000                                   2.272126
# 294           4.069283  2.890372                                   3.539993
# 295           1.360977 -3.000000                                   1.945910
# 296           1.909543 -3.000000                                   0.565314
# 297           1.388791 -3.000000                                   1.249902
#
#      Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                            4.983675                         0.940007
# 1                            5.989187                         1.690096
# 2                            5.057010                        -0.030459
# 3                            5.911907                        -1.203973
# 4                            6.965833                         2.323123
# ..                                ...                              ...
# 293                          3.865770                        -0.287682
# 294                          4.997888                         1.483875
# 295                          3.837299                         0.000000
# 296                          3.149311                        -3.000000
# 297                          3.651697                        -1.714798
#
#      Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        4.844108                           2.928524
# 1                        2.513656                           3.492560
# 2                        1.244155                           3.179719
# 3                        2.710713                          -3.000000
# 4                        5.046924                           5.604929
# ..                            ...                                ...
# 293                     -0.223144                           3.148882
# 294                      2.924236                           3.096256
# 295                      0.000000                           2.420368
# 296                     -1.386294                           1.324419
# 297                     -3.000000                           1.916923
#
#      Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  Population  \
# 0           3.988984      1.386294          2.197225   12.236573
# 1           5.267858      2.397895          1.386294   12.236573
# 2           1.945910     -3.000000          0.000000   12.236573
# 3           4.962845      2.708050         -3.000000   12.236573
# 4           5.771441      3.417727          2.564949   12.236573
# ..               ...           ...               ...         ...
# 293         1.386294     -3.000000         -3.000000    8.159947
# 294         4.204693      1.504077          1.791759    9.375177
# 295         3.135494     -3.000000          0.000000    8.038189
# 296         3.091042     -3.000000         -3.000000    8.370779
# 297         2.995732     -3.000000         -3.000000    8.613230
#
#      Capital_Examens_biologiques  Capital_telemed
# 0                      11.852429         0.693147
# 1                      -3.000000         1.098612
# 2                      -3.000000         0.693147
# 3                      -3.000000        -3.000000
# 4                      14.424276         1.098612
# ..                           ...              ...
# 293                    -3.000000        -3.000000
# 294                    12.956158         0.000000
# 295                    -3.000000         1.945910
# 296                    -3.000000        -3.000000
# 297                    -3.000000        -3.000000
#
# [298 rows x 13 columns]

# %%
analyse_dep_faibles_X = sm.add_constant(analyse_dep_faibles_X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_dep_faibles[['Points_ISA']]

model_dep_faibles = sm.OLS(y, analyse_dep_faibles_X)
results_dep_faibles = model_dep_faibles.fit()
print(results_dep_faibles.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     189.1
# Date:                Fri, 14 May 2021   Prob (F-statistic):          2.09e-131
# Time:                        17:22:09   Log-Likelihood:                -259.17
# No. Observations:                 298   AIC:                             546.3
# Df Residuals:                     284   BIC:                             598.1
# Df Model:                          13
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         7.8372      0.419     18.706      0.000       7.013       8.662
# Personnel médical                             0.2221      0.047      4.709      0.000       0.129       0.315
# Internes                                      0.0905      0.020      4.619      0.000       0.052       0.129
# Personnels de direction et administratifs    -0.0724      0.080     -0.903      0.367      -0.230       0.085
# Personnels des services de soins              0.3677      0.110      3.331      0.001       0.150       0.585
# Personnels éducatifs et sociaux               0.0019      0.036      0.053      0.958      -0.069       0.072
# Personnels médico-techniques                  0.0994      0.033      3.004      0.003       0.034       0.165
# Personnels techniques et ouvriers            -0.0945      0.035     -2.703      0.007      -0.163      -0.026
# Capital_Lit_MCO                               0.3034      0.055      5.547      0.000       0.196       0.411
# Capital_Bloc                                  0.2320      0.029      8.072      0.000       0.175       0.289
# Capital_imagerie                              0.0010      0.021      0.048      0.962      -0.040       0.042
# Population                                   -0.0273      0.030     -0.920      0.358      -0.086       0.031
# Capital_Examens_biologiques                   0.0146      0.007      1.953      0.052      -0.000       0.029
# Capital_telemed                              -0.0046      0.023     -0.201      0.841      -0.049       0.040
# ==============================================================================
# Omnibus:                      113.948   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              784.054
# Skew:                          -1.387   Prob(JB):                    5.56e-171
# Kurtosis:                      10.447   Cond. No.                         173.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
analyse_dep_eleves_X = sm.add_constant(analyse_dep_eleves_X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_dep_eleves[['Points_ISA']]

model_dep_eleves = sm.OLS(y, analyse_dep_eleves_X)
results_dep_eleves = model_dep_eleves.fit()
print(results_dep_eleves.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     123.3
# Date:                Fri, 14 May 2021   Prob (F-statistic):          4.98e-106
# Time:                        17:22:09   Log-Likelihood:                -280.51
# No. Observations:                 287   AIC:                             589.0
# Df Residuals:                     273   BIC:                             640.3
# Df Model:                          13
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         9.7667      0.355     27.550      0.000       9.069      10.465
# Personnel médical                             0.0264      0.047      0.556      0.579      -0.067       0.120
# Internes                                      0.0755      0.020      3.765      0.000       0.036       0.115
# Personnels de direction et administratifs    -0.0110      0.080     -0.137      0.891      -0.169       0.147
# Personnels des services de soins              0.1315      0.090      1.461      0.145      -0.046       0.309
# Personnels éducatifs et sociaux              -0.0369      0.033     -1.125      0.262      -0.101       0.028
# Personnels médico-techniques                  0.0948      0.036      2.626      0.009       0.024       0.166
# Personnels techniques et ouvriers             0.0189      0.051      0.368      0.713      -0.082       0.120
# Capital_Lit_MCO                               0.2616      0.051      5.087      0.000       0.160       0.363
# Capital_Bloc                                  0.3118      0.029     10.853      0.000       0.255       0.368
# Capital_imagerie                              0.0729      0.023      3.207      0.001       0.028       0.118
# Population                                   -0.0568      0.021     -2.650      0.009      -0.099      -0.015
# Capital_Examens_biologiques                   0.0269      0.008      3.189      0.002       0.010       0.044
# Capital_telemed                               0.0680      0.026      2.572      0.011       0.016       0.120
# ==============================================================================
# Omnibus:                       25.706   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.653
# Skew:                           0.374   Prob(JB):                     2.04e-15
# Kurtosis:                       5.258   Cond. No.                         134.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Deuxième analyse : effet de la moyenne des salaires des cadres sur l'emploi de personnel médical libéral

# %%
VAR_EXPL_CAT
# Out:
#       Unnamed: 0 Numero_finess  Médecins libéraux  \
# 0              0     010007300                4.5
# 1              1     010008407                0.0
# 2              2     010009132                0.0
# 3              3     010780054                4.5
# 4              4     010780062                0.0
# ...          ...           ...                ...
# 1147        1147     950300277               29.5
# 1148        1148     950300301                2.0
# 1149        1149     950300350                5.5
# 1150        1150     950630012                0.0
# 1151        1151     950807982               33.0
#
#       Autres personnels médicaux libéraux  Médecins salariés  \
# 0                                     3.0              0.000
# 1                                     0.0             18.490
# 2                                     0.0              1.795
# 3                                     1.0            102.600
# 4                                     0.0             19.450
# ...                                   ...                ...
# 1147                                 16.0              4.060
# 1148                                  0.5              6.970
# 1149                                  6.5              1.000
# 1150                                  0.0             11.300
# 1151                                 38.5              1.300
#
#       Autres personnels médicaux salariés  \
# 0                                    0.00
# 1                                   14.33
# 2                                    0.07
# 3                                   44.53
# 4                                   10.10
# ...                                   ...
# 1147                                 3.00
# 1148                                 1.80
# 1149                                 0.80
# 1150                                 2.50
# 1151                                 3.00
#
#       Personnels de direction et administratifs  \
# 0                                      2.250000
# 1                                     21.196667
# 2                                      4.175000
# 3                                    118.605000
# 4                                     58.450000
# ...                                         ...
# 1147                                  74.950000
# 1148                                  22.560000
# 1149                                   6.600000
# 1150                                  23.070000
# 1151                                  61.000000
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             4.200000                              NaN
# 1                            97.323333                         0.846667
# 2                            46.700000                         1.065000
# 3                           388.590000                         4.930000
# 4                           336.540000                         5.450000
# ...                                ...                              ...
# 1147                        246.990000                         1.100000
# 1148                        103.560000                         1.380000
# 1149                         27.550000                              NaN
# 1150                        177.880000                        39.070000
# 1151                        288.230000                         1.130000
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                              NaN                                NaN
# 1                         9.206667                             26.440
# 2                         1.130000                             13.465
# 3                       107.660000                            112.630
# 4                        29.320000                             57.570
# ...                            ...                                ...
# 1147                      6.460000                             14.460
# 1148                      2.940000                              3.000
# 1149                      3.000000                              1.000
# 1150                      5.330000                             12.700
# 1151                      7.690000                              6.000
#
#          Points_ISA  stjr  Internes  Personnel médical  \
# 0       3785.960000     2      0.00              7.500
# 1     165054.798333     1      0.00             32.820
# 2       5715.170000     1      0.00              1.865
# 3     787929.068333     1    195.09            152.630
# 4     188174.950000     1      6.45             29.550
# ...             ...   ...       ...                ...
# 1147  140779.191667     2      0.00             52.560
# 1148    6779.931667     2      0.00             11.270
# 1149   11099.390000     2      0.00             13.800
# 1150   20931.220000     3      2.49             13.800
# 1151  177318.826667     2      0.00             75.800
#
#       Personnel médical si LIB=0.1  Personnel médical si LIB=0.9
# 0                            1.500                        13.500
# 1                           32.820                        32.820
# 2                            1.865                         1.865
# 3                          148.230                       157.030
# 4                           29.550                        29.550
# ...                            ...                           ...
# 1147                        16.160                        88.960
# 1148                         9.270                        13.270
# 1149                         4.200                        23.400
# 1150                        13.800                        13.800
# 1151                        18.600                       133.000
#
# [1152 rows x 17 columns]

# %%
VAR_EXPL_CAT_2 = VAR_EXPL_CAT.copy()

# %%
VAR_EXPL_CAT_2['Personnel médical salarié'] = VAR_EXPL_CAT['Médecins salariés'] + VAR_EXPL_CAT["Autres personnels médicaux salariés"]
VAR_EXPL_CAT_2['Personnel médical libéral'] = VAR_EXPL_CAT['Médecins libéraux'] + VAR_EXPL_CAT["Autres personnels médicaux libéraux"]

# %%
VAR_EXPL_CAT_2 = VAR_EXPL_CAT_2[['Numero_finess', 'Personnel médical salarié','Personnel médical libéral','stjr',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes']]
VAR_EXPL_CAT_2= VAR_EXPL_CAT_2.fillna(0)

# %%
VAR_EXPL_CAT_2
# Out:
#      Numero_finess  Personnel médical salarié  Personnel médical libéral  \
# 0        010007300                      0.000                        7.5
# 1        010008407                     32.820                        0.0
# 2        010009132                      1.865                        0.0
# 3        010780054                    147.130                        5.5
# 4        010780062                     29.550                        0.0
# ...            ...                        ...                        ...
# 1147     950300277                      7.060                       45.5
# 1148     950300301                      8.770                        2.5
# 1149     950300350                      1.800                       12.0
# 1150     950630012                     13.800                        0.0
# 1151     950807982                      4.300                       71.5
#
#       stjr  Personnels de direction et administratifs  \
# 0        2                                   2.250000
# 1        1                                  21.196667
# 2        1                                   4.175000
# 3        1                                 118.605000
# 4        1                                  58.450000
# ...    ...                                        ...
# 1147     2                                  74.950000
# 1148     2                                  22.560000
# 1149     2                                   6.600000
# 1150     3                                  23.070000
# 1151     2                                  61.000000
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             4.200000                         0.000000
# 1                            97.323333                         0.846667
# 2                            46.700000                         1.065000
# 3                           388.590000                         4.930000
# 4                           336.540000                         5.450000
# ...                                ...                              ...
# 1147                        246.990000                         1.100000
# 1148                        103.560000                         1.380000
# 1149                         27.550000                         0.000000
# 1150                        177.880000                        39.070000
# 1151                        288.230000                         1.130000
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                         0.000000                              0.000
# 1                         9.206667                             26.440
# 2                         1.130000                             13.465
# 3                       107.660000                            112.630
# 4                        29.320000                             57.570
# ...                            ...                                ...
# 1147                      6.460000                             14.460
# 1148                      2.940000                              3.000
# 1149                      3.000000                              1.000
# 1150                      5.330000                             12.700
# 1151                      7.690000                              6.000
#
#       Internes
# 0         0.00
# 1         0.00
# 2         0.00
# 3       195.09
# 4         6.45
# ...        ...
# 1147      0.00
# 1148      0.00
# 1149      0.00
# 1150      2.49
# 1151      0.00
#
# [1152 rows x 10 columns]

# %%
VAR_EXPL_CAT_2 = VAR_EXPL_CAT_2.apply(lambda x: np.log(x) if x.name in ['Personnel médical salarié','Personnel médical libéral',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_EXPL_CAT_2 = VAR_EXPL_CAT_2.replace(-inf, -3)

VAR_EXPL_CAT_2
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Numero_finess  Personnel médical salarié  Personnel médical libéral  \
# 0        010007300                  -3.000000                   2.014903
# 1        010008407                   3.491038                  -3.000000
# 2        010009132                   0.623261                  -3.000000
# 3        010780054                   4.991317                   1.704748
# 4        010780062                   3.386084                  -3.000000
# ...            ...                        ...                        ...
# 1147     950300277                   1.954445                   3.817712
# 1148     950300301                   2.171337                   0.916291
# 1149     950300350                   0.587787                   2.484907
# 1150     950630012                   2.624669                  -3.000000
# 1151     950807982                   1.458615                   4.269697
#
#       stjr  Personnels de direction et administratifs  \
# 0        2                                   0.810930
# 1        1                                   3.053844
# 2        1                                   1.429114
# 3        1                                   4.775799
# 4        1                                   4.068172
# ...    ...                                        ...
# 1147     2                                   4.316821
# 1148     2                                   3.116178
# 1149     2                                   1.887070
# 1150     3                                   3.138533
# 1151     2                                   4.110874
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             1.435085                        -3.000000
# 1                             4.578039                        -0.166448
# 2                             3.843744                         0.062975
# 3                             5.962525                         1.595339
# 4                             5.818717                         1.695616
# ...                                ...                              ...
# 1147                          5.509348                         0.095310
# 1148                          4.640151                         0.322083
# 1149                          3.316003                        -3.000000
# 1150                          5.181109                         3.665355
# 1151                          5.663759                         0.122218
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        -3.000000                          -3.000000
# 1                         2.219928                           3.274878
# 2                         0.122218                           2.600094
# 3                         4.678978                           4.724108
# 4                         3.378270                           4.053002
# ...                            ...                                ...
# 1147                      1.865629                           2.671386
# 1148                      1.078410                           1.098612
# 1149                      1.098612                           0.000000
# 1150                      1.673351                           2.541602
# 1151                      2.039921                           1.791759
#
#       Internes
# 0    -3.000000
# 1    -3.000000
# 2    -3.000000
# 3     5.273461
# 4     1.864080
# ...        ...
# 1147 -3.000000
# 1148 -3.000000
# 1149 -3.000000
# 1150  0.912283
# 1151 -3.000000
#
# [1152 rows x 10 columns]

# %%
VAR_CTRL.describe()
# Out:
#          Points_ISA         stjr  Capital_Lit_MCO  Capital_Bloc  \
# count  1.162000e+03  1162.000000      1139.000000   1153.000000
# mean   2.939915e+05     1.707401       125.109263      7.379577
# std    6.281782e+05     0.716795       127.684194      7.191520
# min    1.347900e+02     1.000000         0.000000      0.000000
# 25%    2.993899e+04     1.000000        35.000000      1.000000
# 50%    1.016205e+05     2.000000        85.000000      6.000000
# 75%    2.975944e+05     2.000000       171.166667     10.500000
# max    9.116903e+06     3.000000      1055.000000     44.000000
#
#        Capital_imagerie  Capital_Examens_biologiques  Capital_telemed  \
# count       1162.000000                 1.149000e+03      1162.000000
# mean           4.256971                 2.508881e+05         0.728148
# std            5.047103                 6.567670e+05         1.514649
# min            0.000000                 0.000000e+00         0.000000
# 25%            0.000000                 0.000000e+00         0.000000
# 50%            3.000000                 0.000000e+00         0.000000
# 75%            7.000000                 6.261400e+04         1.000000
# max           28.000000                 1.060114e+07        11.000000
#
#           SEJHC_MED     SEJHC_CHI    SEJHC_OBS     SEJHC_MCO  \
# count   1162.000000   1162.000000  1161.000000   1162.000000
# mean    3953.236728   2091.528256   673.093714   6717.279443
# std     5172.505167   2471.292213  1146.876402   7600.700172
# min        0.000000      0.000000     0.000000      0.000000
# 25%      364.750000      0.000000     0.000000   1204.500000
# 50%     1963.000000   1428.000000     0.000000   4168.500000
# 75%     5581.250000   3168.312500  1081.000000   9749.750000
# max    39884.000000  20991.000000  7639.000000  60719.000000
#
#        Taux_chomage_par_dep    Population  Dep Moyenne Salaires Horaires  \
# count           1162.000000  1.162000e+03                    1162.000000
# mean               8.290103  1.367009e+05                      11.793749
# std                1.660836  3.998901e+05                       1.908702
# min                5.000000  1.820000e+02                       9.862500
# 25%                7.000000  8.053750e+03                      10.633333
# 50%                8.000000  2.295500e+04                      11.204762
# 75%                9.300000  6.171825e+04                      11.981429
# max               13.800000  2.125851e+06                      17.800000
#
#        Dep Moyenne Salaires Cadre Horaires  \
# count                          1162.000000
# mean                             21.764363
# std                               1.674054
# min                              19.750000
# 25%                              20.775000
# 50%                              21.280808
# 75%                              22.083750
# max                              27.600000
#
#        Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# count                                       1162.000000
# mean                                          12.674821
# std                                            0.523229
# min                                           11.740000
# 25%                                           12.346721
# 50%                                           12.535714
# 75%                                           12.902500
# max                                           14.185000
#
#        Dep Moyenne Salaires Employé Horaires  \
# count                            1162.000000
# mean                                8.783985
# std                                 0.353571
# min                                 8.261905
# 25%                                 8.555172
# 50%                                 8.700862
# 75%                                 8.848113
# max                                 9.742553
#
#        Moyenne Revenus Fiscaux Départementaux
# count                             1162.000000
# mean                             10648.398451
# std                               2063.805307
# min                               6282.000000
# 25%                               9471.000000
# 50%                              10239.000000
# 75%                              11515.000000
# max                              16895.000000

# %% [markdown]
# On garde les 25% d'hopitaux avec les salaires horaires des cadres les plus bas (<20.7750, et les 25% d'hopitaux avec les salaires horaires les plus élevés.(>22.083750)

# %% [markdown]
# On sépare en deux les hôpitaux : ceux avec les salaires horaires les plus bas et ceux avec les salaires horaires les plus élevés : >21.280808%

# %%
VAR_CTRL_2 = VAR_CTRL.copy()

VAR_CTRL_2 = VAR_CTRL_2.apply(lambda x: np.log(x) if x.name in ['Points_ISA', 'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed', 'Population'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_CTRL_2 = VAR_CTRL_2.replace(-inf, -3)
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Les établissements avec des revenus départements  trés élevés

VAR_CTRL_ELEVES_2 = VAR_CTRL_2.copy()
VAR_CTRL_ELEVES_2= VAR_CTRL_ELEVES_2.rename(columns = {'Dep Moyenne Salaires Cadre Horaires': 'sal_cadre_moyen'})

VAR_CTRL_ELEVES_2= VAR_CTRL_ELEVES_2[VAR_CTRL_ELEVES_2.sal_cadre_moyen >21.280808] #22.083750] 21.280808

# %%
# Les établissements avec des revenus départements trésfaibles

VAR_CTRL_FAIBLES_2 = VAR_CTRL_2.copy()
VAR_CTRL_FAIBLES_2 = VAR_CTRL_FAIBLES_2.rename(columns = {'Dep Moyenne Salaires Cadre Horaires': 'sal_cadre_moyen'})

VAR_CTRL_FAIBLES_2 = VAR_CTRL_FAIBLES_2[VAR_CTRL_FAIBLES_2.sal_cadre_moyen <= 21.280808] #20.7750]

# %%
VAR_CTRL_FAIBLES_2= VAR_CTRL_FAIBLES_2.fillna(0)
VAR_CTRL_ELEVES_2= VAR_CTRL_ELEVES_2.fillna(0)
VAR_EXPL_CAT_2 = VAR_EXPL_CAT_2.fillna(0)
#stjr_1 = stjr_1.fillna(0)

# %%
analyse_sal_faibles = pd.merge(VAR_CTRL_FAIBLES_2, VAR_EXPL_CAT_2)

analyse_sal_eleves = pd.merge(VAR_CTRL_ELEVES_2, VAR_EXPL_CAT_2)

# %%
analyse_sal_faibles_X =analyse_sal_faibles[["Personnel médical salarié",'Personnel médical libéral',"Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie', 'Population',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_sal_faibles_Y =analyse_sal_faibles[['Points_ISA']]
analyse_sal_eleves_X =analyse_sal_eleves[["Personnel médical salarié",'Personnel médical libéral',"Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
       'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie', 'Population',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_dep_eleves_Y =analyse_sal_eleves[['Points_ISA']]

# %%
analyse_sal_faibles_X = sm.add_constant(analyse_sal_faibles_X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_sal_faibles[['Points_ISA']]

model_sal_faibles = sm.OLS(y, analyse_sal_faibles_X)
results_sal_faibles = model_sal_faibles.fit()
print(results_sal_faibles.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     299.1
# Date:                Fri, 14 May 2021   Prob (F-statistic):          7.21e-243
# Time:                        17:22:21   Log-Likelihood:                -504.21
# No. Observations:                 552   AIC:                             1038.
# Df Residuals:                     537   BIC:                             1103.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.4510      0.307     27.520      0.000       7.848       9.054
# Personnel médical salarié                     0.0470      0.028      1.704      0.089      -0.007       0.101
# Personnel médical libéral                    -0.0038      0.014     -0.275      0.783      -0.031       0.023
# Internes                                      0.0940      0.016      5.791      0.000       0.062       0.126
# Personnels de direction et administratifs     0.1297      0.061      2.119      0.035       0.009       0.250
# Personnels des services de soins              0.0890      0.070      1.277      0.202      -0.048       0.226
# Personnels éducatifs et sociaux              -0.0125      0.027     -0.468      0.640      -0.065       0.040
# Personnels médico-techniques                  0.0506      0.025      2.029      0.043       0.002       0.100
# Personnels techniques et ouvriers            -0.0539      0.027     -2.014      0.044      -0.107      -0.001
# Capital_Lit_MCO                               0.4118      0.036     11.290      0.000       0.340       0.484
# Capital_Bloc                                  0.2811      0.021     13.448      0.000       0.240       0.322
# Capital_imagerie                              0.0098      0.017      0.589      0.556      -0.023       0.042
# Population                                    0.0023      0.026      0.088      0.930      -0.049       0.054
# Capital_Examens_biologiques                   0.0179      0.006      3.190      0.002       0.007       0.029
# Capital_telemed                               0.0149      0.017      0.898      0.370      -0.018       0.048
# ==============================================================================
# Omnibus:                      114.873   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1452.982
# Skew:                          -0.494   Prob(JB):                         0.00
# Kurtosis:                      10.887   Cond. No.                         162.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
analyse_sal_eleves_X = sm.add_constant(analyse_sal_eleves_X) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_sal_eleves[['Points_ISA']]

model_sal_eleves = sm.OLS(y, analyse_sal_eleves_X)
results_sal_eleves = model_sal_eleves.fit()
print(results_sal_eleves.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     275.6
# Date:                Fri, 14 May 2021   Prob (F-statistic):          1.09e-246
# Time:                        17:22:22   Log-Likelihood:                -566.86
# No. Observations:                 600   AIC:                             1164.
# Df Residuals:                     585   BIC:                             1230.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.7511      0.249     35.120      0.000       8.262       9.240
# Personnel médical salarié                     0.0328      0.025      1.305      0.193      -0.017       0.082
# Personnel médical libéral                     0.0223      0.014      1.628      0.104      -0.005       0.049
# Internes                                      0.0718      0.015      4.897      0.000       0.043       0.101
# Personnels de direction et administratifs    -0.0003      0.054     -0.006      0.995      -0.105       0.105
# Personnels des services de soins              0.1897      0.060      3.179      0.002       0.073       0.307
# Personnels éducatifs et sociaux               0.0013      0.023      0.056      0.955      -0.044       0.047
# Personnels médico-techniques                  0.1130      0.027      4.256      0.000       0.061       0.165
# Personnels techniques et ouvriers            -0.0440      0.027     -1.653      0.099      -0.096       0.008
# Capital_Lit_MCO                               0.3537      0.029     12.264      0.000       0.297       0.410
# Capital_Bloc                                  0.2763      0.020     13.677      0.000       0.237       0.316
# Capital_imagerie                              0.0367      0.015      2.412      0.016       0.007       0.067
# Population                                   -0.0164      0.015     -1.102      0.271      -0.046       0.013
# Capital_Examens_biologiques                   0.0225      0.006      3.929      0.000       0.011       0.034
# Capital_telemed                               0.0471      0.018      2.679      0.008       0.013       0.082
# ==============================================================================
# Omnibus:                       65.090   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              424.220
# Skew:                           0.148   Prob(JB):                     7.62e-93
# Kurtosis:                       7.109   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Troisième analyse : effet du salaire moyen département des employés sur la participation des personnels des services de soins et des services techniques

# %%
VAR_EXPL_CAT_3 = VAR_EXPL_CAT.copy()

# %%
VAR_EXPL_CAT_3['Personnel médical salarié'] = VAR_EXPL_CAT_3['Médecins salariés'] + VAR_EXPL_CAT_3["Autres personnels médicaux salariés"]
VAR_EXPL_CAT_3['Personnel médical libéral'] = VAR_EXPL_CAT_3['Médecins libéraux'] + VAR_EXPL_CAT_3["Autres personnels médicaux libéraux"]

# %%
VAR_EXPL_CAT_3 = VAR_EXPL_CAT_3[['Numero_finess', 'Personnel médical salarié','Personnel médical libéral','stjr',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes']]
VAR_EXPL_CAT_3= VAR_EXPL_CAT_3.fillna(0)

# %%
VAR_EXPL_CAT_3 = VAR_EXPL_CAT_3.apply(lambda x: np.log(x) if x.name in ['Personnel médical salarié','Personnel médical libéral',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_EXPL_CAT_3 = VAR_EXPL_CAT_3.replace(-inf, -3)

VAR_EXPL_CAT_3
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Numero_finess  Personnel médical salarié  Personnel médical libéral  \
# 0        010007300                  -3.000000                   2.014903
# 1        010008407                   3.491038                  -3.000000
# 2        010009132                   0.623261                  -3.000000
# 3        010780054                   4.991317                   1.704748
# 4        010780062                   3.386084                  -3.000000
# ...            ...                        ...                        ...
# 1147     950300277                   1.954445                   3.817712
# 1148     950300301                   2.171337                   0.916291
# 1149     950300350                   0.587787                   2.484907
# 1150     950630012                   2.624669                  -3.000000
# 1151     950807982                   1.458615                   4.269697
#
#       stjr  Personnels de direction et administratifs  \
# 0        2                                   0.810930
# 1        1                                   3.053844
# 2        1                                   1.429114
# 3        1                                   4.775799
# 4        1                                   4.068172
# ...    ...                                        ...
# 1147     2                                   4.316821
# 1148     2                                   3.116178
# 1149     2                                   1.887070
# 1150     3                                   3.138533
# 1151     2                                   4.110874
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             1.435085                        -3.000000
# 1                             4.578039                        -0.166448
# 2                             3.843744                         0.062975
# 3                             5.962525                         1.595339
# 4                             5.818717                         1.695616
# ...                                ...                              ...
# 1147                          5.509348                         0.095310
# 1148                          4.640151                         0.322083
# 1149                          3.316003                        -3.000000
# 1150                          5.181109                         3.665355
# 1151                          5.663759                         0.122218
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        -3.000000                          -3.000000
# 1                         2.219928                           3.274878
# 2                         0.122218                           2.600094
# 3                         4.678978                           4.724108
# 4                         3.378270                           4.053002
# ...                            ...                                ...
# 1147                      1.865629                           2.671386
# 1148                      1.078410                           1.098612
# 1149                      1.098612                           0.000000
# 1150                      1.673351                           2.541602
# 1151                      2.039921                           1.791759
#
#       Internes
# 0    -3.000000
# 1    -3.000000
# 2    -3.000000
# 3     5.273461
# 4     1.864080
# ...        ...
# 1147 -3.000000
# 1148 -3.000000
# 1149 -3.000000
# 1150  0.912283
# 1151 -3.000000
#
# [1152 rows x 10 columns]

# %%
VAR_CTRL.describe()
# Out:
#          Points_ISA         stjr  Capital_Lit_MCO  Capital_Bloc  \
# count  1.162000e+03  1162.000000      1139.000000   1153.000000
# mean   2.939915e+05     1.707401       125.109263      7.379577
# std    6.281782e+05     0.716795       127.684194      7.191520
# min    1.347900e+02     1.000000         0.000000      0.000000
# 25%    2.993899e+04     1.000000        35.000000      1.000000
# 50%    1.016205e+05     2.000000        85.000000      6.000000
# 75%    2.975944e+05     2.000000       171.166667     10.500000
# max    9.116903e+06     3.000000      1055.000000     44.000000
#
#        Capital_imagerie  Capital_Examens_biologiques  Capital_telemed  \
# count       1162.000000                 1.149000e+03      1162.000000
# mean           4.256971                 2.508881e+05         0.728148
# std            5.047103                 6.567670e+05         1.514649
# min            0.000000                 0.000000e+00         0.000000
# 25%            0.000000                 0.000000e+00         0.000000
# 50%            3.000000                 0.000000e+00         0.000000
# 75%            7.000000                 6.261400e+04         1.000000
# max           28.000000                 1.060114e+07        11.000000
#
#           SEJHC_MED     SEJHC_CHI    SEJHC_OBS     SEJHC_MCO  \
# count   1162.000000   1162.000000  1161.000000   1162.000000
# mean    3953.236728   2091.528256   673.093714   6717.279443
# std     5172.505167   2471.292213  1146.876402   7600.700172
# min        0.000000      0.000000     0.000000      0.000000
# 25%      364.750000      0.000000     0.000000   1204.500000
# 50%     1963.000000   1428.000000     0.000000   4168.500000
# 75%     5581.250000   3168.312500  1081.000000   9749.750000
# max    39884.000000  20991.000000  7639.000000  60719.000000
#
#        Taux_chomage_par_dep    Population  Dep Moyenne Salaires Horaires  \
# count           1162.000000  1.162000e+03                    1162.000000
# mean               8.290103  1.367009e+05                      11.793749
# std                1.660836  3.998901e+05                       1.908702
# min                5.000000  1.820000e+02                       9.862500
# 25%                7.000000  8.053750e+03                      10.633333
# 50%                8.000000  2.295500e+04                      11.204762
# 75%                9.300000  6.171825e+04                      11.981429
# max               13.800000  2.125851e+06                      17.800000
#
#        Dep Moyenne Salaires Cadre Horaires  \
# count                          1162.000000
# mean                             21.764363
# std                               1.674054
# min                              19.750000
# 25%                              20.775000
# 50%                              21.280808
# 75%                              22.083750
# max                              27.600000
#
#        Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# count                                       1162.000000
# mean                                          12.674821
# std                                            0.523229
# min                                           11.740000
# 25%                                           12.346721
# 50%                                           12.535714
# 75%                                           12.902500
# max                                           14.185000
#
#        Dep Moyenne Salaires Employé Horaires  \
# count                            1162.000000
# mean                                8.783985
# std                                 0.353571
# min                                 8.261905
# 25%                                 8.555172
# 50%                                 8.700862
# 75%                                 8.848113
# max                                 9.742553
#
#        Moyenne Revenus Fiscaux Départementaux
# count                             1162.000000
# mean                             10648.398451
# std                               2063.805307
# min                               6282.000000
# 25%                               9471.000000
# 50%                              10239.000000
# 75%                              11515.000000
# max                              16895.000000

# %%
VAR_CTRL_3 = VAR_CTRL.copy()

VAR_CTRL_3 = VAR_CTRL_3.apply(lambda x: np.log(x) if x.name in ['Points_ISA', 'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed', 'Population'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_CTRL_3 = VAR_CTRL_3.replace(-inf, -3)
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# On garde les 25% d'hopitaux avec les salaires horaires des employés les plus bas (<8.555172, et les 25% d'hopitaux avec les salaires horaires les plus élevés.(>8.848113)

# %%
# Les établissements avec des revenus départements  trés élevés

VAR_CTRL_ELEVES_3 = VAR_CTRL_3.copy()
VAR_CTRL_ELEVES_3= VAR_CTRL_ELEVES_3.rename(columns = {'Dep Moyenne Salaires Employé Horaires': 'sal_employes_moyen'})

VAR_CTRL_ELEVES_3= VAR_CTRL_ELEVES_3[VAR_CTRL_ELEVES_3.sal_employes_moyen > 8.700862] # 8.848113]

# %%
# Les établissements avec des revenus départements trésfaibles

VAR_CTRL_FAIBLES_3 = VAR_CTRL_3.copy()
VAR_CTRL_FAIBLES_3 = VAR_CTRL_FAIBLES_3.rename(columns = {'Dep Moyenne Salaires Employé Horaires': 'sal_employe_moyen'})

VAR_CTRL_FAIBLES_3 = VAR_CTRL_FAIBLES_3[VAR_CTRL_FAIBLES_3.sal_employe_moyen <=8.700862] # 8.555172]

# %%
VAR_CTRL_FAIBLES_3= VAR_CTRL_FAIBLES_3.fillna(0)
VAR_CTRL_ELEVES_3= VAR_CTRL_ELEVES_3.fillna(0)
VAR_EXPL_CAT_3 = VAR_EXPL_CAT_3.fillna(0)
#stjr_1 = stjr_1.fillna(0)

# %%
analyse_sal_faibles_3 = pd.merge(VAR_CTRL_FAIBLES_3, VAR_EXPL_CAT_3)

analyse_sal_eleves_3 = pd.merge(VAR_CTRL_ELEVES_3, VAR_EXPL_CAT_3)

# %%
analyse_sal_faibles_X_3 =analyse_sal_faibles_3[["Personnel médical salarié",'Personnel médical libéral',"Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie', 'Population',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_sal_faibles_Y_3 =analyse_sal_faibles_3[['Points_ISA']]
analyse_sal_eleves_X_3 =analyse_sal_eleves_3[["Personnel médical salarié",'Personnel médical libéral',"Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
       'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie', 'Population',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_dep_eleves_Y_3=analyse_sal_eleves_3[['Points_ISA']]

# %%
analyse_sal_faibles_X_3
# Out:
#      Personnel médical salarié  Personnel médical libéral  Internes  \
# 0                     1.979621                   3.941582 -3.000000
# 1                    -3.000000                   4.119037 -3.000000
# 2                     3.813969                   3.511545 -3.000000
# 3                    -3.000000                  -3.000000 -3.000000
# 4                     5.857247                  -3.000000  5.540969
# ..                         ...                        ...       ...
# 560                   3.231989                  -3.000000  0.667829
# 561                   3.932120                   2.014903  2.890372
# 562                  -0.105361                   1.098612 -3.000000
# 563                  -1.386294                   1.871802 -3.000000
# 564                   0.009950                   1.098612 -3.000000
#
#      Personnels de direction et administratifs  \
# 0                                     4.932169
# 1                                     3.933197
# 2                                     4.466598
# 3                                     2.446685
# 4                                     5.296841
# ..                                         ...
# 560                                   3.411148
# 561                                   3.539993
# 562                                   1.945910
# 563                                   0.565314
# 564                                   1.249902
#
#      Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                            5.898554                        -3.000000
# 1                            5.933412                        -0.223144
# 2                            5.874144                         0.350657
# 3                            4.843793                         1.004302
# 4                            7.050556                         3.021644
# ..                                ...                              ...
# 560                          5.165072                         0.693147
# 561                          4.997888                         1.483875
# 562                          3.837299                         0.000000
# 563                          3.149311                        -3.000000
# 564                          3.651697                        -1.714798
#
#      Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        4.252630                           2.702032
# 1                        2.304583                           1.420696
# 2                        3.488903                           2.917230
# 3                        0.000000                           1.321756
# 4                        4.712544                           5.358259
# ..                            ...                                ...
# 560                      3.397858                           3.632309
# 561                      2.924236                           3.096256
# 562                      0.000000                           2.420368
# 563                     -1.386294                           1.324419
# 564                     -3.000000                           1.916923
#
#      Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  Population  \
# 0           5.111988      2.772589          2.397895   11.609517
# 1           5.313206      2.564949         -3.000000   11.609517
# 2           5.267858      2.564949          2.302585   11.083956
# 3           2.890372     -3.000000          0.000000   11.083956
# 4           5.993961      3.784190          3.135494   11.083956
# ..               ...           ...               ...         ...
# 560         3.526361      1.609438          1.098612    8.822764
# 561         4.204693      1.504077          1.791759    9.375177
# 562         3.135494     -3.000000          0.000000    8.038189
# 563         3.091042     -3.000000         -3.000000    8.370779
# 564         2.995732     -3.000000         -3.000000    8.613230
#
#      Capital_Examens_biologiques  Capital_telemed
# 0                      13.839551        -3.000000
# 1                      -3.000000        -3.000000
# 2                      -3.000000        -3.000000
# 3                      -3.000000        -3.000000
# 4                      14.709982         2.014903
# ..                           ...              ...
# 560                    12.367630        -3.000000
# 561                    12.956158         0.000000
# 562                    -3.000000         1.945910
# 563                    -3.000000        -3.000000
# 564                    -3.000000        -3.000000
#
# [565 rows x 14 columns]

# %%
analyse_sal_faibles_X_3 = sm.add_constant(analyse_sal_faibles_X_3) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_sal_faibles_3[['Points_ISA']]

model_sal_faibles_3 = sm.OLS(y, analyse_sal_faibles_X_3)
results_sal_faibles_3 = model_sal_faibles.fit()
print(results_sal_faibles_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     299.1
# Date:                Fri, 14 May 2021   Prob (F-statistic):          7.21e-243
# Time:                        17:24:44   Log-Likelihood:                -504.21
# No. Observations:                 552   AIC:                             1038.
# Df Residuals:                     537   BIC:                             1103.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.4510      0.307     27.520      0.000       7.848       9.054
# Personnel médical salarié                     0.0470      0.028      1.704      0.089      -0.007       0.101
# Personnel médical libéral                    -0.0038      0.014     -0.275      0.783      -0.031       0.023
# Internes                                      0.0940      0.016      5.791      0.000       0.062       0.126
# Personnels de direction et administratifs     0.1297      0.061      2.119      0.035       0.009       0.250
# Personnels des services de soins              0.0890      0.070      1.277      0.202      -0.048       0.226
# Personnels éducatifs et sociaux              -0.0125      0.027     -0.468      0.640      -0.065       0.040
# Personnels médico-techniques                  0.0506      0.025      2.029      0.043       0.002       0.100
# Personnels techniques et ouvriers            -0.0539      0.027     -2.014      0.044      -0.107      -0.001
# Capital_Lit_MCO                               0.4118      0.036     11.290      0.000       0.340       0.484
# Capital_Bloc                                  0.2811      0.021     13.448      0.000       0.240       0.322
# Capital_imagerie                              0.0098      0.017      0.589      0.556      -0.023       0.042
# Population                                    0.0023      0.026      0.088      0.930      -0.049       0.054
# Capital_Examens_biologiques                   0.0179      0.006      3.190      0.002       0.007       0.029
# Capital_telemed                               0.0149      0.017      0.898      0.370      -0.018       0.048
# ==============================================================================
# Omnibus:                      114.873   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1452.982
# Skew:                          -0.494   Prob(JB):                         0.00
# Kurtosis:                      10.887   Cond. No.                         162.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
analyse_sal_eleves_X_3 = sm.add_constant(analyse_sal_eleves_X_3) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_sal_eleves_3[['Points_ISA']]

model_sal_eleves_3 = sm.OLS(y, analyse_sal_eleves_X_3)
results_sal_eleves_3 = model_sal_eleves.fit()
print(results_sal_eleves_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     275.6
# Date:                Fri, 14 May 2021   Prob (F-statistic):          1.09e-246
# Time:                        17:24:45   Log-Likelihood:                -566.86
# No. Observations:                 600   AIC:                             1164.
# Df Residuals:                     585   BIC:                             1230.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.7511      0.249     35.120      0.000       8.262       9.240
# Personnel médical salarié                     0.0328      0.025      1.305      0.193      -0.017       0.082
# Personnel médical libéral                     0.0223      0.014      1.628      0.104      -0.005       0.049
# Internes                                      0.0718      0.015      4.897      0.000       0.043       0.101
# Personnels de direction et administratifs    -0.0003      0.054     -0.006      0.995      -0.105       0.105
# Personnels des services de soins              0.1897      0.060      3.179      0.002       0.073       0.307
# Personnels éducatifs et sociaux               0.0013      0.023      0.056      0.955      -0.044       0.047
# Personnels médico-techniques                  0.1130      0.027      4.256      0.000       0.061       0.165
# Personnels techniques et ouvriers            -0.0440      0.027     -1.653      0.099      -0.096       0.008
# Capital_Lit_MCO                               0.3537      0.029     12.264      0.000       0.297       0.410
# Capital_Bloc                                  0.2763      0.020     13.677      0.000       0.237       0.316
# Capital_imagerie                              0.0367      0.015      2.412      0.016       0.007       0.067
# Population                                   -0.0164      0.015     -1.102      0.271      -0.046       0.013
# Capital_Examens_biologiques                   0.0225      0.006      3.929      0.000       0.011       0.034
# Capital_telemed                               0.0471      0.018      2.679      0.008       0.013       0.082
# ==============================================================================
# Omnibus:                       65.090   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              424.220
# Skew:                           0.148   Prob(JB):                     7.62e-93
# Kurtosis:                       7.109   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Taille des villes : est ce la participation aux Points-ISA est la même dans les grandes et petites villes?

# %% [markdown]
# On prend les 25% des villes avec le moins d'ahbitants, par rapport aux 25% des villes avec le plus d'habitants

# %%
VAR_EXPL_CAT_4 = VAR_EXPL_CAT.copy()

# %%
VAR_EXPL_CAT_4 = VAR_EXPL_CAT_4[['Numero_finess', 'Personnel médical','stjr',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes']]
VAR_EXPL_CAT_4= VAR_EXPL_CAT_4.fillna(0)

# %%
VAR_EXPL_CAT_4 = VAR_EXPL_CAT_4.apply(lambda x: np.log(x) if x.name in ['Personnel médical',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_EXPL_CAT_4 = VAR_EXPL_CAT_4.replace(-inf, -3)

VAR_EXPL_CAT_4
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Numero_finess  Personnel médical  stjr  \
# 0        010007300           2.014903     2
# 1        010008407           3.491038     1
# 2        010009132           0.623261     1
# 3        010780054           5.028017     1
# 4        010780062           3.386084     1
# ...            ...                ...   ...
# 1147     950300277           3.961955     2
# 1148     950300301           2.422144     2
# 1149     950300350           2.624669     2
# 1150     950630012           2.624669     3
# 1151     950807982           4.328098     2
#
#       Personnels de direction et administratifs  \
# 0                                      0.810930
# 1                                      3.053844
# 2                                      1.429114
# 3                                      4.775799
# 4                                      4.068172
# ...                                         ...
# 1147                                   4.316821
# 1148                                   3.116178
# 1149                                   1.887070
# 1150                                   3.138533
# 1151                                   4.110874
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             1.435085                        -3.000000
# 1                             4.578039                        -0.166448
# 2                             3.843744                         0.062975
# 3                             5.962525                         1.595339
# 4                             5.818717                         1.695616
# ...                                ...                              ...
# 1147                          5.509348                         0.095310
# 1148                          4.640151                         0.322083
# 1149                          3.316003                        -3.000000
# 1150                          5.181109                         3.665355
# 1151                          5.663759                         0.122218
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        -3.000000                          -3.000000
# 1                         2.219928                           3.274878
# 2                         0.122218                           2.600094
# 3                         4.678978                           4.724108
# 4                         3.378270                           4.053002
# ...                            ...                                ...
# 1147                      1.865629                           2.671386
# 1148                      1.078410                           1.098612
# 1149                      1.098612                           0.000000
# 1150                      1.673351                           2.541602
# 1151                      2.039921                           1.791759
#
#       Internes
# 0    -3.000000
# 1    -3.000000
# 2    -3.000000
# 3     5.273461
# 4     1.864080
# ...        ...
# 1147 -3.000000
# 1148 -3.000000
# 1149 -3.000000
# 1150  0.912283
# 1151 -3.000000
#
# [1152 rows x 9 columns]

# %%
VAR_CTRL.describe()
# Out:
#          Points_ISA         stjr  Capital_Lit_MCO  Capital_Bloc  \
# count  1.162000e+03  1162.000000      1139.000000   1153.000000
# mean   2.939915e+05     1.707401       125.109263      7.379577
# std    6.281782e+05     0.716795       127.684194      7.191520
# min    1.347900e+02     1.000000         0.000000      0.000000
# 25%    2.993899e+04     1.000000        35.000000      1.000000
# 50%    1.016205e+05     2.000000        85.000000      6.000000
# 75%    2.975944e+05     2.000000       171.166667     10.500000
# max    9.116903e+06     3.000000      1055.000000     44.000000
#
#        Capital_imagerie  Capital_Examens_biologiques  Capital_telemed  \
# count       1162.000000                 1.149000e+03      1162.000000
# mean           4.256971                 2.508881e+05         0.728148
# std            5.047103                 6.567670e+05         1.514649
# min            0.000000                 0.000000e+00         0.000000
# 25%            0.000000                 0.000000e+00         0.000000
# 50%            3.000000                 0.000000e+00         0.000000
# 75%            7.000000                 6.261400e+04         1.000000
# max           28.000000                 1.060114e+07        11.000000
#
#           SEJHC_MED     SEJHC_CHI    SEJHC_OBS     SEJHC_MCO  \
# count   1162.000000   1162.000000  1161.000000   1162.000000
# mean    3953.236728   2091.528256   673.093714   6717.279443
# std     5172.505167   2471.292213  1146.876402   7600.700172
# min        0.000000      0.000000     0.000000      0.000000
# 25%      364.750000      0.000000     0.000000   1204.500000
# 50%     1963.000000   1428.000000     0.000000   4168.500000
# 75%     5581.250000   3168.312500  1081.000000   9749.750000
# max    39884.000000  20991.000000  7639.000000  60719.000000
#
#        Taux_chomage_par_dep    Population  Dep Moyenne Salaires Horaires  \
# count           1162.000000  1.162000e+03                    1162.000000
# mean               8.290103  1.367009e+05                      11.793749
# std                1.660836  3.998901e+05                       1.908702
# min                5.000000  1.820000e+02                       9.862500
# 25%                7.000000  8.053750e+03                      10.633333
# 50%                8.000000  2.295500e+04                      11.204762
# 75%                9.300000  6.171825e+04                      11.981429
# max               13.800000  2.125851e+06                      17.800000
#
#        Dep Moyenne Salaires Cadre Horaires  \
# count                          1162.000000
# mean                             21.764363
# std                               1.674054
# min                              19.750000
# 25%                              20.775000
# 50%                              21.280808
# 75%                              22.083750
# max                              27.600000
#
#        Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# count                                       1162.000000
# mean                                          12.674821
# std                                            0.523229
# min                                           11.740000
# 25%                                           12.346721
# 50%                                           12.535714
# 75%                                           12.902500
# max                                           14.185000
#
#        Dep Moyenne Salaires Employé Horaires  \
# count                            1162.000000
# mean                                8.783985
# std                                 0.353571
# min                                 8.261905
# 25%                                 8.555172
# 50%                                 8.700862
# 75%                                 8.848113
# max                                 9.742553
#
#        Moyenne Revenus Fiscaux Départementaux
# count                             1162.000000
# mean                             10648.398451
# std                               2063.805307
# min                               6282.000000
# 25%                               9471.000000
# 50%                              10239.000000
# 75%                              11515.000000
# max                              16895.000000

# %% [markdown]
# Les 25% des villes avec le moins d'habitants ont une population inférieure 8.055250e+03, tandis que les 25% des vilels avec le plus d'habitants, ont plus de 6.227500e+04 habitants

# %%
VAR_CTRL_4 = VAR_CTRL.copy()

# %%
# Les établissements avec des revenus départements  trés élevés

VAR_CTRL_ELEVES_4 = VAR_CTRL_4.copy()

VAR_CTRL_ELEVES_4= VAR_CTRL_ELEVES_4[VAR_CTRL_ELEVES_4.Population > 2.295500e+04] #62275]

# %%
VAR_CTRL_ELEVES_4
# Out:
#      Numero_finess    Points_ISA  stjr dep            Departement COMINSEE  \
# 0        060000528  3.568920e+05     3  06        Alpes-Maritimes    06088
# 1        060780947  1.745525e+05     3  06        Alpes-Maritimes    06088
# 2        060791811  1.464326e+05     3  06        Alpes-Maritimes    06088
# 3        060780442  2.284238e+04     2  06        Alpes-Maritimes    06088
# 4        060780715  3.420512e+05     2  06        Alpes-Maritimes    06088
# ...            ...           ...   ...  ..                    ...      ...
# 1128     610780082  5.089111e+05     1  61                   Orne    61001
# 1137     850000118  1.780298e+05     2  85                 Vendée    85191
# 1138     850000019  1.517322e+06     1  85                 Vendée    85191
# 1144     900000035  6.794712e+04     2  90  Territoire de Belfort    90010
# 1156     120780044  7.430512e+05     1  12                Aveyron    12202
#
#       Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  \
# 0          128.000000           8.0          9.000000
# 1          105.000000           5.0          4.000000
# 2           91.000000           2.0          2.000000
# 3           30.000000           6.0          1.000000
# 4          256.000000          26.0         10.000000
# ...               ...           ...               ...
# 1128       148.500000           7.0          8.500000
# 1137       110.000000          11.0          0.000000
# 1138       255.333333          22.0         11.333333
# 1144        47.000000           9.0          0.000000
# 1156       309.000000          14.0         10.000000
#
#       Capital_Examens_biologiques  ...    SEJHC_OBS  SEJHC_MCO  \
# 0                           909.0  ...     0.000000     7020.0
# 1                             0.0  ...     0.000000     9754.0
# 2                             0.0  ...     0.000000     2558.0
# 3                             0.0  ...     0.000000     1605.0
# 4                             0.0  ...  1467.000000    15866.0
# ...                           ...  ...          ...        ...
# 1128                     881617.0  ...   642.500000     7531.0
# 1137                          0.0  ...   624.000000     7046.0
# 1138                     901940.0  ...  1281.666667    14659.0
# 1144                          0.0  ...     0.000000     2702.0
# 1156                     952849.0  ...  1990.000000    17581.0
#
#       Taux_chomage_par_dep  Population  Dep Moyenne Salaires Horaires  \
# 0                      8.9    343123.0                      12.579245
# 1                      8.9    343123.0                      12.579245
# 2                      8.9    343123.0                      12.579245
# 3                      8.9    343123.0                      12.579245
# 4                      8.9    343123.0                      12.579245
# ...                    ...         ...                            ...
# 1128                   7.8     28917.0                      10.217647
# 1137                   6.5     49292.0                      10.004412
# 1138                   6.5     49292.0                      10.004412
# 1144                   8.9     50406.0                      11.783333
# 1156                   6.4     23734.0                      10.115789
#
#       Dep Moyenne Salaires Cadre Horaires  \
# 0                               22.518868
# 1                               22.518868
# 2                               22.518868
# 3                               22.518868
# 4                               22.518868
# ...                                   ...
# 1128                            20.252941
# 1137                            20.307353
# 1138                            20.307353
# 1144                            22.208333
# 1156                            20.252632
#
#       Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# 0                                            12.864151
# 1                                            12.864151
# 2                                            12.864151
# 3                                            12.864151
# 4                                            12.864151
# ...                                                ...
# 1128                                         12.100000
# 1137                                         11.870588
# 1138                                         11.870588
# 1144                                         12.225000
# 1156                                         11.963158
#
#       Dep Moyenne Salaires Employé Horaires  \
# 0                                  8.835849
# 1                                  8.835849
# 2                                  8.835849
# 3                                  8.835849
# 4                                  8.835849
# ...                                     ...
# 1128                               8.629412
# 1137                               8.392647
# 1138                               8.392647
# 1144                               8.583333
# 1156                               8.478947
#
#       Moyenne Revenus Fiscaux Départementaux                Bloc_politique
# 0                                    12288.0         Centre droit à droite
# 1                                    12288.0         Centre droit à droite
# 2                                    12288.0         Centre droit à droite
# 3                                    12288.0         Centre droit à droite
# 4                                    12288.0         Centre droit à droite
# ...                                      ...                           ...
# 1128                                  9877.0  Centre gauche à centre droit
# 1137                                 11342.0  Centre gauche à centre droit
# 1138                                 11342.0  Centre gauche à centre droit
# 1144                                 11360.0       Extrême gauche à gauche
# 1156                                  9936.0  Centre gauche à centre droit
#
# [581 rows x 23 columns]

# %%
VAR_CTRL_ELEVES_4 = VAR_CTRL_ELEVES_4.apply(lambda x: np.log(x) if x.name in ['Points_ISA', 'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed', 'Population'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_CTRL_ELEVES_4= VAR_CTRL_ELEVES_4.replace(-inf, -3)
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Les établissements avec des revenus départements trésfaibles

VAR_CTRL_FAIBLES_4 = VAR_CTRL_4.copy()
VAR_CTRL_FAIBLES_4 = VAR_CTRL_FAIBLES_4[VAR_CTRL_FAIBLES_4.Population <= 2.295500e+04]# 8055.250]

# %%
VAR_CTRL_FAIBLES_4 = VAR_CTRL_FAIBLES_4.apply(lambda x: np.log(x) if x.name in ['Points_ISA', 'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed', 'Population'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_CTRL_FAIBLES_4= VAR_CTRL_FAIBLES_4.replace(-inf, -3)
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
VAR_CTRL_FAIBLES_4= VAR_CTRL_FAIBLES_4.fillna(0)
VAR_CTRL_ELEVES_4= VAR_CTRL_ELEVES_4.fillna(0)
VAR_EXPL_CAT_4 = VAR_EXPL_CAT_4.fillna(0)
#stjr_1 = stjr_1.fillna(0)

# %%
analyse_pop_faibles_4 = pd.merge(VAR_CTRL_FAIBLES_4, VAR_EXPL_CAT_4)

analyse_pop_eleves_4 = pd.merge(VAR_CTRL_ELEVES_4, VAR_EXPL_CAT_4)

# %%
analyse_pop_eleves_4
# Out:
#     Numero_finess  Points_ISA  stjr dep            Departement COMINSEE  \
# 0       060000528   12.785189     3  06        Alpes-Maritimes    06088
# 1       060780947   12.069981     3  06        Alpes-Maritimes    06088
# 2       060791811   11.894321     3  06        Alpes-Maritimes    06088
# 3       060780442   10.036373     2  06        Alpes-Maritimes    06088
# 4       060780715   12.742716     2  06        Alpes-Maritimes    06088
# ..            ...         ...   ...  ..                    ...      ...
# 569     610780082   13.140029     1  61                   Orne    61001
# 570     850000118   12.089706     2  85                 Vendée    85191
# 571     850000019   14.232458     1  85                 Vendée    85191
# 572     900000035   11.126485     2  90  Territoire de Belfort    90010
# 573     120780044   13.518520     1  12                Aveyron    12202
#
#      Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  \
# 0           4.852030      2.079442          2.197225
# 1           4.653960      1.609438          1.386294
# 2           4.510860      0.693147          0.693147
# 3           3.401197      1.791759          0.000000
# 4           5.545177      3.258097          2.302585
# ..               ...           ...               ...
# 569         5.000585      1.945910          2.140066
# 570         4.700480      2.397895         -3.000000
# 571         5.542570      3.091042          2.427748
# 572         3.850148      2.197225         -3.000000
# 573         5.733341      2.639057          2.302585
#
#      Capital_Examens_biologiques  ...  Dep Moyenne Salaires Employé Horaires  \
# 0                       6.812345  ...                               8.835849
# 1                      -3.000000  ...                               8.835849
# 2                      -3.000000  ...                               8.835849
# 3                      -3.000000  ...                               8.835849
# 4                      -3.000000  ...                               8.835849
# ..                           ...  ...                                    ...
# 569                    13.689513  ...                               8.629412
# 570                    -3.000000  ...                               8.392647
# 571                    13.712303  ...                               8.392647
# 572                    -3.000000  ...                               8.583333
# 573                    13.767212  ...                               8.478947
#
#      Moyenne Revenus Fiscaux Départementaux                Bloc_politique  \
# 0                                   12288.0         Centre droit à droite
# 1                                   12288.0         Centre droit à droite
# 2                                   12288.0         Centre droit à droite
# 3                                   12288.0         Centre droit à droite
# 4                                   12288.0         Centre droit à droite
# ..                                      ...                           ...
# 569                                  9877.0  Centre gauche à centre droit
# 570                                 11342.0  Centre gauche à centre droit
# 571                                 11342.0  Centre gauche à centre droit
# 572                                 11360.0       Extrême gauche à gauche
# 573                                  9936.0  Centre gauche à centre droit
#
#      Personnel médical  Personnels de direction et administratifs  \
# 0             4.512287                                   4.983333
# 1             4.289089                                   4.721708
# 2             3.331133                                   3.820565
# 3             3.465736                                   2.833213
# 4             4.844187                                   4.423768
# ..                 ...                                        ...
# 569           4.639700                                   4.017524
# 570           3.618993                                   3.281287
# 571           5.036411                                   4.892152
# 572           3.054001                                   3.030134
# 573           4.880957                                   4.132282
#
#      Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                            5.774707                         1.510722
# 1                            5.860444                         0.810930
# 2                            5.505941                         1.278152
# 3                            4.320151                         0.000000
# 4                            6.041207                        -0.301105
# ..                                ...                              ...
# 569                          5.780723                         1.040277
# 570                          5.189228                        -0.223144
# 571                          6.667622                         2.142808
# 572                          4.750482                         0.000000
# 573                          5.688161                         2.319114
#
#      Personnels médico-techniques  Personnels techniques et ouvriers  Internes
# 0                        5.106794                           3.672242  4.521897
# 1                        3.074543                           2.955431  4.683242
# 2                        2.013569                           3.710886  2.943913
# 3                        1.098612                           1.945910 -3.000000
# 4                        3.083743                           2.896464 -3.000000
# ..                            ...                                ...       ...
# 569                      3.464172                           4.079738  3.779634
# 570                      1.774952                          -3.000000  1.098612
# 571                      4.347823                           4.821813  4.752526
# 572                      1.335001                           2.803360 -3.000000
# 573                      3.916413                           4.335655  4.410978
#
# [574 rows x 30 columns]

# %%
analyse_pop_faibles_X_4 =analyse_pop_faibles_4[["Personnel médical","Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_pop_faibles_Y_4 =analyse_pop_faibles_4[['Points_ISA']]
analyse_pop_eleves_X_4 =analyse_pop_eleves_4[["Personnel médical","Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
       'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_pop_eleves_Y_4=analyse_pop_eleves_4[['Points_ISA']]

# %%
analyse_pop_faibles_X_4 = sm.add_constant(analyse_pop_faibles_X_4) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_pop_faibles_4[['Points_ISA']]

model_pop_faibles_4 = sm.OLS(y, analyse_pop_faibles_X_4)
results_pop_faibles_4 = model_pop_faibles_4.fit()
print(results_pop_faibles_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.851
# Method:                 Least Squares   F-statistic:                     276.5
# Date:                Fri, 14 May 2021   Prob (F-statistic):          2.28e-227
# Time:                        17:26:29   Log-Likelihood:                -578.22
# No. Observations:                 578   AIC:                             1182.
# Df Residuals:                     565   BIC:                             1239.
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.5833      0.223     38.441      0.000       8.145       9.022
# Personnel médical                             0.1161      0.030      3.931      0.000       0.058       0.174
# Internes                                      0.0839      0.015      5.564      0.000       0.054       0.114
# Personnels de direction et administratifs     0.1185      0.065      1.818      0.070      -0.010       0.246
# Personnels des services de soins              0.0387      0.065      0.598      0.550      -0.089       0.166
# Personnels éducatifs et sociaux               0.0202      0.027      0.738      0.461      -0.034       0.074
# Personnels médico-techniques                  0.0914      0.030      3.012      0.003       0.032       0.151
# Personnels techniques et ouvriers            -0.1005      0.031     -3.255      0.001      -0.161      -0.040
# Capital_Lit_MCO                               0.4057      0.032     12.823      0.000       0.344       0.468
# Capital_Bloc                                  0.2226      0.020     11.304      0.000       0.184       0.261
# Capital_imagerie                              0.0293      0.018      1.630      0.104      -0.006       0.065
# Capital_Examens_biologiques                   0.0247      0.006      4.252      0.000       0.013       0.036
# Capital_telemed                               0.0040      0.017      0.237      0.812      -0.029       0.037
# ==============================================================================
# Omnibus:                       77.451   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              560.991
# Skew:                          -0.300   Prob(JB):                    1.52e-122
# Kurtosis:                       7.789   Cond. No.                         72.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
analyse_pop_eleves_X_4
# Out:
#      Personnel médical  Internes  Personnels de direction et administratifs  \
# 0             4.512287  4.521897                                   4.983333
# 1             4.289089  4.683242                                   4.721708
# 2             3.331133  2.943913                                   3.820565
# 3             3.465736 -3.000000                                   2.833213
# 4             4.844187 -3.000000                                   4.423768
# ..                 ...       ...                                        ...
# 569           4.639700  3.779634                                   4.017524
# 570           3.618993  1.098612                                   3.281287
# 571           5.036411  4.752526                                   4.892152
# 572           3.054001 -3.000000                                   3.030134
# 573           4.880957  4.410978                                   4.132282
#
#      Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                            5.774707                         1.510722
# 1                            5.860444                         0.810930
# 2                            5.505941                         1.278152
# 3                            4.320151                         0.000000
# 4                            6.041207                        -0.301105
# ..                                ...                              ...
# 569                          5.780723                         1.040277
# 570                          5.189228                        -0.223144
# 571                          6.667622                         2.142808
# 572                          4.750482                         0.000000
# 573                          5.688161                         2.319114
#
#      Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        5.106794                           3.672242
# 1                        3.074543                           2.955431
# 2                        2.013569                           3.710886
# 3                        1.098612                           1.945910
# 4                        3.083743                           2.896464
# ..                            ...                                ...
# 569                      3.464172                           4.079738
# 570                      1.774952                          -3.000000
# 571                      4.347823                           4.821813
# 572                      1.335001                           2.803360
# 573                      3.916413                           4.335655
#
#      Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  \
# 0           4.852030      2.079442          2.197225
# 1           4.653960      1.609438          1.386294
# 2           4.510860      0.693147          0.693147
# 3           3.401197      1.791759          0.000000
# 4           5.545177      3.258097          2.302585
# ..               ...           ...               ...
# 569         5.000585      1.945910          2.140066
# 570         4.700480      2.397895         -3.000000
# 571         5.542570      3.091042          2.427748
# 572         3.850148      2.197225         -3.000000
# 573         5.733341      2.639057          2.302585
#
#      Capital_Examens_biologiques  Capital_telemed
# 0                       6.812345         0.000000
# 1                      -3.000000         0.693147
# 2                      -3.000000        -3.000000
# 3                      -3.000000        -3.000000
# 4                      -3.000000        -3.000000
# ..                           ...              ...
# 569                    13.689513         0.405465
# 570                    -3.000000        -3.000000
# 571                    13.712303         1.945910
# 572                    -3.000000        -3.000000
# 573                    13.767212        -3.000000
#
# [574 rows x 12 columns]

# %%
analyse_pop_eleves_X_4 = sm.add_constant(analyse_pop_eleves_X_4) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_pop_eleves_4[['Points_ISA']]

model_pop_eleves_4 = sm.OLS(y, analyse_pop_eleves_X_4)
results_pop_eleves_4 = model_pop_eleves_4.fit()
print(results_pop_eleves_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     350.5
# Date:                Fri, 14 May 2021   Prob (F-statistic):          1.73e-251
# Time:                        17:26:32   Log-Likelihood:                -462.56
# No. Observations:                 574   AIC:                             951.1
# Df Residuals:                     561   BIC:                             1008.
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.0340      0.226     35.594      0.000       7.591       8.477
# Personnel médical                             0.0335      0.033      1.029      0.304      -0.030       0.097
# Internes                                      0.0797      0.013      6.175      0.000       0.054       0.105
# Personnels de direction et administratifs    -0.0564      0.048     -1.169      0.243      -0.151       0.038
# Personnels des services de soins              0.3425      0.061      5.603      0.000       0.222       0.463
# Personnels éducatifs et sociaux              -0.0227      0.019     -1.172      0.242      -0.061       0.015
# Personnels médico-techniques                  0.0671      0.021      3.245      0.001       0.026       0.108
# Personnels techniques et ouvriers            -0.0117      0.022     -0.527      0.598      -0.055       0.032
# Capital_Lit_MCO                               0.3325      0.032     10.494      0.000       0.270       0.395
# Capital_Bloc                                  0.3110      0.020     15.254      0.000       0.271       0.351
# Capital_imagerie                              0.0212      0.013      1.625      0.105      -0.004       0.047
# Capital_Examens_biologiques                   0.0168      0.005      3.282      0.001       0.007       0.027
# Capital_telemed                               0.0609      0.016      3.701      0.000       0.029       0.093
# ==============================================================================
# Omnibus:                       86.645   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1025.857
# Skew:                          -0.066   Prob(JB):                    1.73e-223
# Kurtosis:                       9.548   Cond. No.                         118.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Départements de gauche ou de droite : leur effet sur la production

# %%
VAR_EXPL_CAT_5 = VAR_EXPL_CAT.copy()

# %%
VAR_EXPL_CAT_5 = VAR_EXPL_CAT_5[['Numero_finess', 'Personnel médical','stjr',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes']]
VAR_EXPL_CAT_5 = VAR_EXPL_CAT_5.fillna(0)

# %%
VAR_EXPL_CAT_5 = VAR_EXPL_CAT_5.apply(lambda x: np.log(x) if x.name in ['Personnel médical',
       'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers',
        'Internes'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_EXPL_CAT_5 = VAR_EXPL_CAT_5.replace(-inf, -3)

VAR_EXPL_CAT_5
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Numero_finess  Personnel médical  stjr  \
# 0        010007300           2.014903     2
# 1        010008407           3.491038     1
# 2        010009132           0.623261     1
# 3        010780054           5.028017     1
# 4        010780062           3.386084     1
# ...            ...                ...   ...
# 1147     950300277           3.961955     2
# 1148     950300301           2.422144     2
# 1149     950300350           2.624669     2
# 1150     950630012           2.624669     3
# 1151     950807982           4.328098     2
#
#       Personnels de direction et administratifs  \
# 0                                      0.810930
# 1                                      3.053844
# 2                                      1.429114
# 3                                      4.775799
# 4                                      4.068172
# ...                                         ...
# 1147                                   4.316821
# 1148                                   3.116178
# 1149                                   1.887070
# 1150                                   3.138533
# 1151                                   4.110874
#
#       Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                             1.435085                        -3.000000
# 1                             4.578039                        -0.166448
# 2                             3.843744                         0.062975
# 3                             5.962525                         1.595339
# 4                             5.818717                         1.695616
# ...                                ...                              ...
# 1147                          5.509348                         0.095310
# 1148                          4.640151                         0.322083
# 1149                          3.316003                        -3.000000
# 1150                          5.181109                         3.665355
# 1151                          5.663759                         0.122218
#
#       Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        -3.000000                          -3.000000
# 1                         2.219928                           3.274878
# 2                         0.122218                           2.600094
# 3                         4.678978                           4.724108
# 4                         3.378270                           4.053002
# ...                            ...                                ...
# 1147                      1.865629                           2.671386
# 1148                      1.078410                           1.098612
# 1149                      1.098612                           0.000000
# 1150                      1.673351                           2.541602
# 1151                      2.039921                           1.791759
#
#       Internes
# 0    -3.000000
# 1    -3.000000
# 2    -3.000000
# 3     5.273461
# 4     1.864080
# ...        ...
# 1147 -3.000000
# 1148 -3.000000
# 1149 -3.000000
# 1150  0.912283
# 1151 -3.000000
#
# [1152 rows x 9 columns]

# %%
VAR_CTRL.groupby("Bloc_politique").count()
# Out:
#                               Numero_finess  Points_ISA  stjr  dep  \
# Bloc_politique
# Centre droit à droite                   146         146   146  146
# Centre gauche à centre droit            556         556   556  556
# Droite à extrême droite                 287         287   287  287
# Extrême gauche à gauche                 173         173   173  173
#
#                               Departement  COMINSEE  Capital_Lit_MCO  \
# Bloc_politique
# Centre droit à droite                 146       146              144
# Centre gauche à centre droit          556       556              541
# Droite à extrême droite               287       287              282
# Extrême gauche à gauche               173       173              172
#
#                               Capital_Bloc  Capital_imagerie  \
# Bloc_politique
# Centre droit à droite                  145               146
# Centre gauche à centre droit           552               556
# Droite à extrême droite                283               287
# Extrême gauche à gauche                173               173
#
#                               Capital_Examens_biologiques  ...  SEJHC_CHI  \
# Bloc_politique                                             ...
# Centre droit à droite                                 145  ...        146
# Centre gauche à centre droit                          550  ...        556
# Droite à extrême droite                               283  ...        287
# Extrême gauche à gauche                               171  ...        173
#
#                               SEJHC_OBS  SEJHC_MCO  Taux_chomage_par_dep  \
# Bloc_politique
# Centre droit à droite               146        146                   146
# Centre gauche à centre droit        555        556                   556
# Droite à extrême droite             287        287                   287
# Extrême gauche à gauche             173        173                   173
#
#                               Population  Dep Moyenne Salaires Horaires  \
# Bloc_politique
# Centre droit à droite                146                            146
# Centre gauche à centre droit         556                            556
# Droite à extrême droite              287                            287
# Extrême gauche à gauche              173                            173
#
#                               Dep Moyenne Salaires Cadre Horaires  \
# Bloc_politique
# Centre droit à droite                                         146
# Centre gauche à centre droit                                  556
# Droite à extrême droite                                       287
# Extrême gauche à gauche                                       173
#
#                               Dep Moyenne Salaires Prof Intermédiaire Horaires  \
# Bloc_politique
# Centre droit à droite                                                      146
# Centre gauche à centre droit                                               556
# Droite à extrême droite                                                    287
# Extrême gauche à gauche                                                    173
#
#                               Dep Moyenne Salaires Employé Horaires  \
# Bloc_politique
# Centre droit à droite                                           146
# Centre gauche à centre droit                                    556
# Droite à extrême droite                                         287
# Extrême gauche à gauche                                         173
#
#                               Moyenne Revenus Fiscaux Départementaux
# Bloc_politique
# Centre droit à droite                                            146
# Centre gauche à centre droit                                     556
# Droite à extrême droite                                          287
# Extrême gauche à gauche                                          173
#
# [4 rows x 22 columns]

# %%
# Les établissements avec des revenus départements  trés élevés

VAR_CTRL_GAUCHE_5 = VAR_CTRL.copy()

VAR_CTRL_GAUCHE_5 = VAR_CTRL_GAUCHE_5.apply(lambda x: np.log(x) if x.name in ['Points_ISA', 'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed', 'Population'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_CTRL_GAUCHE_5= VAR_CTRL_GAUCHE_5.replace(-inf, -3)

VAR_CTRL_GAUCHE_5_1= VAR_CTRL_GAUCHE_5[VAR_CTRL_GAUCHE_5.Bloc_politique == "Centre gauche à centre droit"]
VAR_CTRL_GAUCHE_5_2 = VAR_CTRL_GAUCHE_5[VAR_CTRL_GAUCHE_5.Bloc_politique == "Extrême gauche à gauche"]
VAR_CTRL_GAUCHE_5 = pd.concat([VAR_CTRL_GAUCHE_5_1,VAR_CTRL_GAUCHE_5_2])
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
VAR_CTRL_DROITE_5 = VAR_CTRL.copy()

VAR_CTRL_DROITE_5 = VAR_CTRL_DROITE_5.apply(lambda x: np.log(x) if x.name in ['Points_ISA', 'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed', 'Population'] else x)

#On remplace les valeurs -infini apparues après l'application du log par la valeur -3 c'est-à-dire log(0.001)
from numpy import inf
VAR_CTRL_DROITE_5= VAR_CTRL_DROITE_5.replace(-inf, -3)

VAR_CTRL_DROITE_5_1= VAR_CTRL_DROITE_5[VAR_CTRL_DROITE_5.Bloc_politique == "Centre droit à droite"]
VAR_CTRL_DROITE_5_2 = VAR_CTRL_DROITE_5[VAR_CTRL_DROITE_5.Bloc_politique == "Droite à extrême droite"]
VAR_CTRL_DROITE_5 = pd.concat([VAR_CTRL_DROITE_5_1,VAR_CTRL_DROITE_5_2])
# Out:
# C:\Users\Vinciane\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
VAR_CTRL_DROITE_5= VAR_CTRL_DROITE_5.fillna(0)
VAR_CTRL_GAUCHE_5 = VAR_CTRL_GAUCHE_5.fillna(0)
VAR_EXPL_CAT_5 = VAR_EXPL_CAT_5.fillna(0)
#stjr_1 = stjr_1.fillna(0)

# %%
analyse_dep_gauche_5 = pd.merge(VAR_CTRL_GAUCHE_5, VAR_EXPL_CAT_5)

analyse_dep_droite_5 = pd.merge(VAR_CTRL_DROITE_5, VAR_EXPL_CAT_5)

# %%
analyse_dep_gauche_X_5 =analyse_dep_gauche_5[["Personnel médical","Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
        'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_dep_gauche_Y_5 =analyse_dep_gauche_5[['Points_ISA']]
analyse_dep_droite_X_5 =analyse_dep_droite_5[["Personnel médical","Internes",'Personnels de direction et administratifs',
       'Personnels des services de soins', 'Personnels éducatifs et sociaux',
       'Personnels médico-techniques', 'Personnels techniques et ouvriers', 
       'Capital_Lit_MCO', 'Capital_Bloc', 'Capital_imagerie',
       'Capital_Examens_biologiques', 'Capital_telemed']]
analyse_dep_droite_Y_5 =analyse_dep_droite_5[['Points_ISA']]

# %%
analyse_dep_gauche_X_5 = sm.add_constant(analyse_dep_gauche_X_5) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_dep_gauche_5[['Points_ISA']]

model_dep_gauche_5 = sm.OLS(y, analyse_dep_gauche_X_5)
results_dep_gauche_5 = model_dep_gauche_5.fit()
print(results_dep_gauche_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     479.4
# Date:                Fri, 14 May 2021   Prob (F-statistic):               0.00
# Time:                        17:52:27   Log-Likelihood:                -637.74
# No. Observations:                 722   AIC:                             1301.
# Df Residuals:                     709   BIC:                             1361.
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.1176      0.199     40.716      0.000       7.726       8.509
# Personnel médical                             0.0789      0.027      2.967      0.003       0.027       0.131
# Internes                                      0.0865      0.012      7.466      0.000       0.064       0.109
# Personnels de direction et administratifs    -0.0526      0.053     -0.987      0.324      -0.157       0.052
# Personnels des services de soins              0.2404      0.060      3.979      0.000       0.122       0.359
# Personnels éducatifs et sociaux              -0.0276      0.020     -1.409      0.159      -0.066       0.011
# Personnels médico-techniques                  0.0747      0.021      3.508      0.000       0.033       0.116
# Personnels techniques et ouvriers            -0.0286      0.021     -1.332      0.183      -0.071       0.014
# Capital_Lit_MCO                               0.3964      0.026     15.147      0.000       0.345       0.448
# Capital_Bloc                                  0.2690      0.018     15.371      0.000       0.235       0.303
# Capital_imagerie                              0.0235      0.013      1.831      0.068      -0.002       0.049
# Capital_Examens_biologiques                   0.0212      0.005      4.530      0.000       0.012       0.030
# Capital_telemed                               0.0332      0.015      2.254      0.024       0.004       0.062
# ==============================================================================
# Omnibus:                      104.392   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1234.829
# Skew:                           0.018   Prob(JB):                    7.25e-269
# Kurtosis:                       9.407   Cond. No.                         99.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
analyse_dep_droite_X_5
# Out:
#      Personnel médical  Internes  Personnels de direction et administratifs  \
# 0             4.512287  4.521897                                   4.983333
# 1             4.289089  4.683242                                   4.721708
# 2             3.331133  2.943913                                   3.820565
# 3             3.465736 -3.000000                                   2.833213
# 4             4.844187 -3.000000                                   4.423768
# ..                 ...       ...                                        ...
# 425           4.388630  2.794228                                   4.670864
# 426           3.351657  2.197225                                   4.266335
# 427           4.502029  4.084631                                   3.698731
# 428           1.838961  1.497388                                   2.770086
# 429           2.978586  2.173615                                   3.234749
#
#      Personnels des services de soins  Personnels éducatifs et sociaux  \
# 0                            5.774707                         1.510722
# 1                            5.860444                         0.810930
# 2                            5.505941                         1.278152
# 3                            4.320151                         0.000000
# 4                            6.041207                        -0.301105
# ..                                ...                              ...
# 425                          6.369867                         2.832036
# 426                          6.189065                         3.666378
# 427                          5.175630                         1.816452
# 428                          4.262539                         0.182322
# 429                          4.740225                         0.672944
#
#      Personnels médico-techniques  Personnels techniques et ouvriers  \
# 0                        5.106794                           3.672242
# 1                        3.074543                           2.955431
# 2                        2.013569                           3.710886
# 3                        1.098612                           1.945910
# 4                        3.083743                           2.896464
# ..                            ...                                ...
# 425                      3.376221                           4.743540
# 426                      1.386294                           4.528937
# 427                      3.036234                           3.765435
# 428                      1.477049                           3.336837
# 429                      2.607861                           2.686486
#
#      Capital_Lit_MCO  Capital_Bloc  Capital_imagerie  \
# 0           4.852030      2.079442          2.197225
# 1           4.653960      1.609438          1.386294
# 2           4.510860      0.693147          0.693147
# 3           3.401197      1.791759          0.000000
# 4           5.545177      3.258097          2.302585
# ..               ...           ...               ...
# 425         5.099866      1.791759          1.386294
# 426         1.609438     -3.000000         -3.000000
# 427         5.575949      2.302585          1.386294
# 428         3.465736     -3.000000          1.386294
# 429         3.401197      0.693147          0.693147
#
#      Capital_Examens_biologiques  Capital_telemed
# 0                       6.812345         0.000000
# 1                      -3.000000         0.693147
# 2                      -3.000000        -3.000000
# 3                      -3.000000        -3.000000
# 4                      -3.000000        -3.000000
# ..                           ...              ...
# 425                    -3.000000         1.386294
# 426                    -3.000000         1.386294
# 427                    13.703321        -3.000000
# 428                    -3.000000        -3.000000
# 429                    11.819358         0.000000
#
# [430 rows x 12 columns]

# %%
analyse_dep_droite_X_5 = sm.add_constant(analyse_dep_droite_X_5) # on ajoute une constante, sinon la régression se fait sans, par défaut
y = analyse_dep_droite_5[['Points_ISA']]

model_dep_droite_5 = sm.OLS(y, analyse_dep_droite_X_5)
results_dep_droite_5 = model_dep_droite_5.fit()
print(results_dep_droite_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Points_ISA   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     211.5
# Date:                Fri, 14 May 2021   Prob (F-statistic):          7.72e-169
# Time:                        17:52:27   Log-Likelihood:                -417.90
# No. Observations:                 430   AIC:                             861.8
# Df Residuals:                     417   BIC:                             914.6
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         8.7653      0.249     35.196      0.000       8.276       9.255
# Personnel médical                             0.1143      0.036      3.211      0.001       0.044       0.184
# Internes                                      0.0704      0.018      3.911      0.000       0.035       0.106
# Personnels de direction et administratifs     0.1118      0.062      1.810      0.071      -0.010       0.233
# Personnels des services de soins              0.1098      0.066      1.662      0.097      -0.020       0.240
# Personnels éducatifs et sociaux               0.0427      0.029      1.472      0.142      -0.014       0.100
# Personnels médico-techniques                  0.0782      0.032      2.432      0.015       0.015       0.141
# Personnels techniques et ouvriers            -0.0818      0.033     -2.492      0.013      -0.146      -0.017
# Capital_Lit_MCO                               0.2913      0.040      7.220      0.000       0.212       0.371
# Capital_Bloc                                  0.2565      0.023     11.265      0.000       0.212       0.301
# Capital_imagerie                              0.0361      0.020      1.792      0.074      -0.004       0.076
# Capital_Examens_biologiques                   0.0212      0.007      3.132      0.002       0.008       0.035
# Capital_telemed                               0.0227      0.020      1.142      0.254      -0.016       0.062
# ==============================================================================
# Omnibus:                       69.855   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              453.232
# Skew:                          -0.478   Prob(JB):                     3.82e-99
# Kurtosis:                       7.938   Cond. No.                         78.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## tests pour sortie les résultats en image

# %%
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 7))

plt.text(0.01, 0.05, str(results_pop_eleves_4.summary()), {'fontsize': 10}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()
plt.savefig('output.png')
